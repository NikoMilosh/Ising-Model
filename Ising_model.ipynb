# %% [markdown]
# $\underline{\large{Ising-Model}}$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
from scipy.optimize import curve_fit

# %%
processed_path='/Users/milos/Desktop/Data/Theomess.txt'
Theo=pd.read_csv(processed_path,sep='\s+',header=None)
Theo = pd.DataFrame(Theo)

TheoTemp=Theo[0]

TheoMag=Theo[1]

Theoenergy=Theo[2]

TheoC=Theo[3]

TheoX=Theo[4]

# %%
processed_path='/Users/milos/Desktop/Data/b_0_2_size_42_sweeps_10000.txt'
Data02=pd.read_csv(processed_path,sep='\s+',header=None)
Data02 = pd.DataFrame(Data02)


processed_path='/Users/milos/Desktop/Data/b_0_25_size_42_sweeps_10000.txt'
Data025=pd.read_csv(processed_path,sep='\s+',header=None)
Data025 = pd.DataFrame(Data025)

processed_path='/Users/milos/Desktop/Data/b_0_3_size_42_sweeps_10000.txt'
Data03=pd.read_csv(processed_path,sep='\s+',header=None)
Data03 = pd.DataFrame(Data03)

processed_path='/Users/milos/Desktop/Data/b_0_4_size_42_sweeps_10000.txt'
Data04=pd.read_csv(processed_path,sep='\s+',header=None)
Data04 = pd.DataFrame(Data04)

processed_path='/Users/milos/Desktop/Data/b_0_425_size_42_sweeps_10000.txt'
Data0425=pd.read_csv(processed_path,sep='\s+',header=None)
Data0425 = pd.DataFrame(Data0425)

processed_path='/Users/milos/Desktop/Data/b_0_45_size_42_sweeps_10000.txt'
Data045=pd.read_csv(processed_path,sep='\s+',header=None)
Data045 = pd.DataFrame(Data045)

processed_path='/Users/milos/Desktop/Data/b_0_475_size_42_sweeps_10000.txt'
Data0475=pd.read_csv(processed_path,sep='\s+',header=None)
Data0475 = pd.DataFrame(Data0475)

processed_path='/Users/milos/Desktop/Data/b_0_5_size_42_sweeps_10000.txt'
Data05=pd.read_csv(processed_path,sep='\s+',header=None)
Data05 = pd.DataFrame(Data05)

processed_path='/Users/milos/Desktop/Data/b_0_6_size_42_sweeps_10000.txt'
Data06=pd.read_csv(processed_path,sep='\s+',header=None)
Data06 = pd.DataFrame(Data06)

processed_path='/Users/milos/Desktop/Data/b_0_7_size_42_sweeps_10000.txt'
Data07=pd.read_csv(processed_path,sep='\s+',header=None)
Data07 = pd.DataFrame(Data07)

processed_path='/Users/milos/Desktop/Data/b_0_8_size_42_sweeps_10000.txt'
Data08=pd.read_csv(processed_path,sep='\s+',header=None)
Data08 = pd.DataFrame(Data08)

processed_path='/Users/milos/Desktop/Data/b_0_9_size_42_sweeps_10000.txt'
Data09=pd.read_csv(processed_path,sep='\s+',header=None)
Data09 = pd.DataFrame(Data09)

processed_path='/Users/milos/Desktop/Data/b_1_0_size_42_sweeps_10000.txt'
Data1=pd.read_csv(processed_path,sep='\s+',header=None)
Data1 = pd.DataFrame(Data1)

# %%
mag02=Data02[0]
energy02=Data02[1]

mag025=Data025[0]
energy025=Data025[1]

mag03=Data03[0]
energy03=Data03[1]

mag04=Data04[0]
energy04=Data04[1]

mag0425=Data0425[0]
energy0424=Data0425[1]

mag045=Data045[0]
energy045=Data045[1]

mag0475=Data0475[0]
energy0475=Data0475[1]

mag05=Data05[0]
energy05=Data05[1]

mag06=Data06[0]
energy06=Data06[1]

mag07=Data07[0]
energy07=Data07[1]

mag08=Data08[0]
energy08=Data08[1]

mag09=Data09[0]
energy09=Data09[1]

mag1=Data1[0]
energy1=Data1[1]

# %%
processed_path='/Users/milos/Desktop/Data/Hyst_0_25.txt'
HData025=pd.read_csv(processed_path,sep='\s+',header=None)
HData025 = pd.DataFrame(HData025)

Hmag025=HData025[0]
Henergy025=HData025[1]

processed_path='/Users/milos/Desktop/Data/Hyst_0_2.txt'
HData02=pd.read_csv(processed_path,sep='\s+',header=None)
HData02 = pd.DataFrame(HData02)

Hmag02=HData02[0]
Henergy02=HData02[1]

processed_path='/Users/milos/Desktop/Data/Hyst_0_15.txt'
HData015=pd.read_csv(processed_path,sep='\s+',header=None)
HData015 = pd.DataFrame(HData015)

Hmag015=HData015[0]
Henergy015=HData015[1]


processed_path='/Users/milos/Desktop/Data/Hyst_0_1.txt'
HData01=pd.read_csv(processed_path,sep='\s+',header=None)
HData01 = pd.DataFrame(HData01)

Hmag01=HData01[0]
Henergy01=HData01[1]


processed_path='/Users/milos/Desktop/Data/Hyst_0_05.txt'
HData005=pd.read_csv(processed_path,sep='\s+',header=None)
HData005= pd.DataFrame(HData005)

Hmag005=HData005[0]
Henergy005=HData005[1]

processed_path='/Users/milos/Desktop/Data/Hyst_0_0.txt'
HData00=pd.read_csv(processed_path,sep='\s+',header=None)
HData00= pd.DataFrame(HData00)

Hmag00=HData00[0]
Henergy00=HData00[1]

#Negative values


#back to positive

processed_path='/Users/milos/Desktop/Data/Hyst_b_0_1.txt'
bHData01=pd.read_csv(processed_path,sep='\s+',header=None)
bHData01= pd.DataFrame(bHData01)

bHmag01=bHData01[0]
bHenergy01=bHData01[1]

processed_path='/Users/milos/Desktop/Data/Hyst_b_0_15.txt'
bHData015=pd.read_csv(processed_path,sep='\s+',header=None)
bHData015= pd.DataFrame(bHData015)

bHmag015=bHData015[0]
bHenergy015=bHData015[1]



processed_path='/Users/milos/Desktop/Data/Hyst_b_0_26.txt'
bHData026=pd.read_csv(processed_path,sep='\s+',header=None)
bHData026= pd.DataFrame(bHData026)

bHmag026=bHData026[0]
bHenergy026=bHData026[1]

processed_path='/Users/milos/Desktop/Data/Hyst_b_0_4.txt'
bHData04=pd.read_csv(processed_path,sep='\s+',header=None)
bHData04= pd.DataFrame(bHData04)

bHmag04=bHData04[0]
bHenergy04=bHData04[1]

processed_path='/Users/milos/Desktop/Data/Hyst_b_0_5.txt'
bHData05=pd.read_csv(processed_path,sep='\s+',header=None)
bHData05= pd.DataFrame(bHData05)

bHmag05=bHData05[0]
bHenergy05=bHData05[1]

processed_path='/Users/milos/Desktop/Data/Hyst_b_0_65.txt'
bHData065=pd.read_csv(processed_path,sep='\s+',header=None)
bHData065= pd.DataFrame(bHData065)

bHmag065=bHData065[0]
bHenergy065=bHData065[1]

processed_path='/Users/milos/Desktop/Data/Hyst_b_0_9.txt'
bHData09=pd.read_csv(processed_path,sep='\s+',header=None)
bHData09= pd.DataFrame(bHData09)

bHmag09=bHData09[0]
bHenergy09=bHData09[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_2_0.txt'
bHData2=pd.read_csv(processed_path,sep='\s+',header=None)
bHData2= pd.DataFrame(bHData2)

bHmag2=bHData2[0]
bHenergy2=bHData2[1]

#back back

processed_path='/Users/milos/Desktop/Data/Hyst_bb_1_5.txt'
bbHData15=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData15= pd.DataFrame(bbHData15)

bbHmag15=bbHData15[0]
bbHenergy15=bbHData15[1]



processed_path='/Users/milos/Desktop/Data/Hyst_bb_1.txt'
bbHData1=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData1= pd.DataFrame(bbHData1)

bbHmag1=bbHData1[0]
bbHenergy1=bbHData1[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_7.txt'
bbHData07=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData07= pd.DataFrame(bbHData07)

bbHmag07=bbHData07[0]
bbHenergy07=bbHData07[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_6.txt'
bbHData06=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData06= pd.DataFrame(bbHData06)

bbHmag06=bbHData06[0]
bbHenergy06=bbHData06[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_5.txt'
bbHData05=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData05= pd.DataFrame(bbHData05)

bbHmag05=bbHData05[0]
bbHenergy05=bbHData05[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_475.txt'
bbHData0475=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData0475= pd.DataFrame(bbHData0475)

bbHmag0475=bbHData0475[0]
bbHenergy0475=bbHData0475[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_45.txt'
bbHData045=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData045= pd.DataFrame(bbHData045)

bbHmag045=bbHData045[0]
bbHenergy045=bbHData045[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_4.txt'
bbHData04=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData04= pd.DataFrame(bbHData04)

bbHmag04=bbHData04[0]
bbHenergy04=bbHData04[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_4_T2.txt'
TbbHData04=pd.read_csv(processed_path,sep='\s+',header=None)
TbbHData04= pd.DataFrame(TbbHData04)

TbbHmag04=TbbHData04[0]
TbbHenergy04=TbbHData04[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_35.txt'
bbHData035=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData035= pd.DataFrame(bbHData035)

bbHmag035=bbHData035[0]
bbHenergy035=bbHData035[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_3.txt'
bbHData03=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData03= pd.DataFrame(bbHData03)

bbHmag03=bbHData03[0]
bbHenergy03=bbHData03[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_2.txt'
bbHData02=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData02= pd.DataFrame(bbHData02)

bbHmag02=bbHData02[0]
bbHenergy02=bbHData02[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_0.txt'
bbHData00=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData00= pd.DataFrame(bbHData00)

bbHmag00=bbHData00[0]
bbHenergy00=bbHData00[1]

# %%
Magn=np.array([np.mean(mag07),np.mean(mag06),np.mean(mag05),np.mean(mag04),np.mean(mag03),np.mean(mag02)])
T=np.array([1,2,3,4,5,6])
plt.plot(T,Magn/max(Magn),'x')

# %%
plt.figure(figsize=(20,10))
sweeps=np.linspace(1,len(mag025),num=len(mag025))
sweep5=np.mean(mag025[:5])
x=np.linspace(1,len(energy025),num=len(energy025[::50]))
plt.plot(list(x),list(energy025[::50]),'x-')

# %%
sweep1=np.mean(mag025[:1])
sweep5=np.mean(mag025[:5])
sweep10=np.mean(mag025[:9])
sweep20=np.mean(mag025[:19])
sweep50=np.mean(mag025[:49])
sweep100=np.mean(mag025[:99])
sweep200=np.mean(mag025[:199])
sweep400=np.mean(mag025[:399])
sweep500=np.mean(mag025[:499])
sweep1000=np.mean(mag025[:999])
sweep2000=np.mean(mag025[:1999])
sweep5000=np.mean(mag025[:4999])
sweep7000=np.mean(mag025[:6999])
sweep10000=np.mean(mag025)

sw1=np.mean(mag02[:1])
sw5=np.mean(mag02[:5])
sw10=np.mean(mag02[:9])
sw20=np.mean(mag02[:19])
sw50=np.mean(mag02[:49])
sw100=np.mean(mag02[:99])
sw200=np.mean(mag02[:199])
sw400=np.mean(mag02[:399])
sw500=np.mean(mag02[:499])
sw1000=np.mean(mag02[:999])
sw2000=np.mean(mag02[:1999])
sw5000=np.mean(mag02[:4999])
sw7000=np.mean(mag02[:6999])
sw10000=np.mean(mag02)

s1=np.mean(mag03[:1])
s5=np.mean(mag03[:5])
s10=np.mean(mag03[:9])
s20=np.mean(mag03[:19])
s50=np.mean(mag03[:49])
s100=np.mean(mag03[:99])
s200=np.mean(mag03[:199])
s400=np.mean(mag03[:399])
s500=np.mean(mag03[:499])
s1000=np.mean(mag03[:999])
s2000=np.mean(mag03[:1999])
s5000=np.mean(mag03[:4999])
s7000=np.mean(mag03[:6999])
s10000=np.mean(mag03)

s1_04=np.mean(mag04[:1])
s5_04=np.mean(mag04[:5])
s10_04=np.mean(mag04[:9])
s20_04=np.mean(mag04[:19])
s50_04=np.mean(mag04[:49])
s100_04=np.mean(mag04[:99])
s200_04=np.mean(mag04[:199])
s400_04=np.mean(mag04[:399])
s500_04=np.mean(mag04[:499])
s1000_04=np.mean(mag04[:999])
s2000_04=np.mean(mag04[:1999])
s5000_04=np.mean(mag04[:4999])
s7000_04=np.mean(mag04[:6999])
s10000_04=np.mean(mag04)

s1_05=np.mean(mag05[:1])
s5_05=np.mean(mag05[:5])
s10_05=np.mean(mag05[:9])
s20_05=np.mean(mag05[:19])
s50_05=np.mean(mag05[:49])
s100_05=np.mean(mag05[:99])
s200_05=np.mean(mag05[:199])
s400_05=np.mean(mag05[:399])
s500_05=np.mean(mag05[:499])
s1000_05=np.mean(mag05[:999])
s2000_05=np.mean(mag05[:1999])
s5000_05=np.mean(mag05[:4999])
s7000_05=np.mean(mag05[:6999])
s10000_05=np.mean(mag05)

s1_06=np.mean(mag06[:1])
s5_06=np.mean(mag06[:5])
s10_06=np.mean(mag06[:9])
s20_06=np.mean(mag06[:19])
s50_06=np.mean(mag06[:49])
s100_06=np.mean(mag06[:99])
s200_06=np.mean(mag06[:199])
s400_06=np.mean(mag06[:399])
s500_06=np.mean(mag06[:499])
s1000_06=np.mean(mag06[:999])
s2000_06=np.mean(mag06[:1999])
s5000_06=np.mean(mag06[:4999])
s7000_06=np.mean(mag06[:6999])
s10000_06=np.mean(mag06)

s1_07=np.mean(mag07[:1])
s5_07=np.mean(mag07[:5])
s10_07=np.mean(mag07[:9])
s20_07=np.mean(mag07[:19])
s50_07=np.mean(mag07[:49])
s100_07=np.mean(mag07[:99])
s200_07=np.mean(mag07[:199])
s400_07=np.mean(mag07[:399])
s500_07=np.mean(mag07[:499])
s1000_07=np.mean(mag07[:999])
s2000_07=np.mean(mag07[:1999])
s5000_07=np.mean(mag07[:4999])
s7000_07=np.mean(mag07[:6999])
s10000_07=np.mean(mag07)

average_mag_0_7_error=np.array([np.var(mag07[:1]),np.var(mag07[:5]),np.var(mag07[:9]),np.var(mag07[:19]),
                                np.var(mag07[:49]),np.var(mag07[:99]),np.var(mag07[:199]),np.var(mag07[:399]),
                                np.var(mag07[:499]),np.var(mag07[:999]),np.var(mag07[:1999]),np.var(mag07[:499]),
                                np.var(mag07[:6999]),np.var(mag07)])

average_mag_0_4_error=np.array([np.var(mag04[:1]),np.var(mag04[:5]),np.var(mag04[:9]),np.var(mag07[:19]),
                                np.var(mag04[:49]),np.var(mag04[:99]),np.var(mag04[:199]),np.var(mag07[:399]),
                                np.var(mag04[:499]),np.var(mag04[:999]),np.var(mag04[:1999]),np.var(mag07[:499]),
                                np.var(mag04[:6999]),np.var(mag04)])

average_mag_0_2_error=np.array([np.var(mag02[:1]),np.var(mag02[:5]),np.var(mag02[:9]),np.var(mag02[:19]),
                                np.var(mag02[:49]),np.var(mag02[:99]),np.var(mag02[:199]),np.var(mag02[:399]),
                                np.var(mag02[:499]),np.var(mag02[:999]),np.var(mag02[:1999]),np.var(mag02[:499]),
                                np.var(mag02[:6999]),np.var(mag02)])



average_mag_0_2=np.array([sw1,sw5,sw10,sw20,sw50,
                      sw100,sw200,sw400,sw500,
                      sw1000,sw2000,sw5000,sw7000,sw10000])



average_mag_0_25=np.array([sweep1,sweep5,sweep10,sweep20,sweep50,
                      sweep100,sweep200,sweep400,sweep500,
                      sweep1000,sweep2000,sweep5000,sweep7000,sweep10000])

average_mag_0_3=np.array([s1,s5,s10,s20,s50,
                      s100,s200,s400,s500,
                      s1000,s2000,s5000,s7000,s10000])

average_mag_0_4=np.array([s1_04,s5_04,s10_04,s20_04,s50_04,
                      s100_04,s200_04,s400_04,s500_04,
                      s1000_04,s2000_04,s5000_04,s7000_04,s10000_04])

average_mag_0_5=np.array([s1_05,s5_05,s10_05,s20_05,s50_05,
                      s100_05,s200_05,s400_05,s500_05,
                      s1000_05,s2000_05,s5000_05,s7000_05,s10000_05])

average_mag_0_6=np.array([s1_06,s5_06,s10_06,s20_06,s50_06,
                      s100_06,s200_06,s400_06,s500_06,
                      s1000_06,s2000_06,s5000_06,s7000_06,s10000_06])




average_mag_0_7=np.array([s1_07,s5_07,s10_07,s20_07,s50_07,
                      s100_07,s200_07,s400_07,s500_07,
                      s1000_07,s2000_07,s5000_07,s7000_07,s10000_07])









as_sweeps=np.array([1,5,10,20,50,100,200,400,500,1000,2000,5000,7000,10000])

# %%
en1=np.mean(energy02[:1])
en5=np.mean(energy02[:5])
en10=np.mean(energy02[:9])
en20=np.mean(energy02[:19])
en50=np.mean(energy02[:49])
en100=np.mean(energy02[:99])
en200=np.mean(energy02[:199])
en400=np.mean(energy02[:399])
en500=np.mean(energy02[:499])
en1000=np.mean(energy02[:999])
en2000=np.mean(energy02[:1999])
en5000=np.mean(energy02[:4999])
en7000=np.mean(energy02[:6999])
en10000=np.mean(energy02)

en1_04=np.mean(energy04[:1])
en5_04=np.mean(energy04[:5])
en10_04=np.mean(energy04[:9])
en20_04=np.mean(energy04[:19])
en50_04=np.mean(energy04[:49])
en100_04=np.mean(energy04[:99])
en200_04=np.mean(energy04[:199])
en400_04=np.mean(energy04[:399])
en500_04=np.mean(energy04[:499])
en1000_04=np.mean(energy04[:999])
en2000_04=np.mean(energy04[:1999])
en5000_04=np.mean(energy04[:4999])
en7000_04=np.mean(energy04[:6999])
en10000_04=np.mean(energy04)

en1_07=np.mean(energy07[:1])
en5_07=np.mean(energy07[:5])
en10_07=np.mean(energy07[:9])
en20_07=np.mean(energy07[:19])
en50_07=np.mean(energy07[:49])
en100_07=np.mean(energy07[:99])
en200_07=np.mean(energy07[:199])
en400_07=np.mean(energy07[:399])
en500_07=np.mean(energy07[:499])
en1000_07=np.mean(energy07[:999])
en2000_07=np.mean(energy07[:1999])
en5000_07=np.mean(energy07[:4999])
en7000_07=np.mean(energy07[:6999])
en10000_07=np.mean(energy07)

average_en_0_2=np.array([en1,en5,en10,en20,en50,en100,
                      en200,en400,en500,en1000,en2000,
                      en5000,en7000,en10000])



average_en_0_4=np.array([en1_04,en5_04,en10_04,en20_04,en50_04,
                      en100_04,en200_04,en400_04,en500_04,
                      en1000_04,en2000_04,en5000_04,en7000_04,en10000_04])

average_en_0_7=np.array([en1_07,en5_07,en10_07,en20_07,en50_07,
                      en100_07,en200_07,en400_07,en500_07,
                      en1000_07,en2000_07,en5000_07,en7000_07,en10000_07])


average_en_0_7_error=np.array([np.var(energy07[:1]),np.var(energy07[:5]),np.var(energy07[:9]),
                               np.var(energy07[:19]),np.var(energy07[:49]),np.var(energy07[:99]),
                                  np.var(energy07[:199]),np.var(energy07[:399]),np.var(energy07[:499]),
                               np.var(energy07[:999]),np.var(energy07[:1999]),np.var(energy07[:4999]),
                      np.var(energy07[:6999]),np.var(energy07)])



average_en_0_4_error=np.array([np.var(energy04[:1]),np.var(energy04[:5]),np.var(energy04[:9]),
                               np.var(energy04[:19]),np.var(energy04[:49]),np.var(energy04[:99]),
                                  np.var(energy04[:199]),np.var(energy04[:399]),np.var(energy04[:499]),np.var(energy04[:999]),
                               np.var(energy04[:1999]),np.var(energy04[:4999]),
                      np.var(energy04[:6999]),np.var(energy04)])

average_en_0_2_error=np.array([np.var(energy02[:1]),np.var(energy02[:5]),np.var(energy02[:9]),
                               np.var(energy02[:19]),np.var(energy02[:49]),np.var(energy02[:99]),
                                  np.var(energy02[:199]),np.var(energy02[:399]),np.var(energy02[:499]),np.var(energy02[:999]),
                               np.var(energy02[:1999]),np.var(energy02[:4999]),
                      np.var(energy02[:6999]),np.var(energy02)])







as_sweeps=np.array([1,5,10,20,50,100,200,400,500,1000,2000,5000,7000,10000])

# %% [markdown]
# ## Exercise 1

# %%
plt.figure(figsize=(10,5))

plt.plot(as_sweeps,average_en_0_2/max(average_en_0_2)*4,'lightgrey',label=r'$\beta =0.7$')

plt.plot(as_sweeps,average_en_0_4/max(average_en_0_4)*4,'k-',color='grey',label=r'$\beta =0.4$')

plt.plot(as_sweeps,(average_en_0_7/max(average_en_0_7)*100-99)*4,'k-',color='k',label=r'$\beta =0.2$')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('Sweeps',fontsize=30)
plt.ylabel('Energy per spin',fontsize=30)

plt.legend(fontsize=20)

#plt.savefig('En_stabilization.png', bbox_inches='tight')
# Out:
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/2193100381.py:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(as_sweeps,average_en_0_4/max(average_en_0_4)*4,'k-',color='grey',label=r'$\beta =0.4$')
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/2193100381.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(as_sweeps,(average_en_0_7/max(average_en_0_7)*100-99)*4,'k-',color='k',label=r'$\beta =0.2$')

# %%
plt.figure(figsize=(10,10))


plt.plot(as_sweeps,-(average_en_0_7),'x-',color='k',label=r'$\beta =0.7$')
plt.errorbar(as_sweeps,-average_en_0_7, yerr=average_en_0_7_error, fmt=' ',color='k',capsize=3)



plt.plot(as_sweeps,-average_en_0_4,'-',color='grey',label=r'$\beta =0.4$')
plt.errorbar(as_sweeps,-average_en_0_4, yerr=average_en_0_4_error, fmt=' ',color='grey',capsize=3)



plt.plot(as_sweeps,-average_en_0_2,'x--',color='lightgrey',label=r'$\beta =0.2$')
plt.errorbar(as_sweeps,-average_en_0_2, yerr=average_en_0_2_error, fmt=' ',color='lightgrey',capsize=3)







plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('MC Sweeps',fontsize=30)
plt.ylabel('Energy per spin',fontsize=30)

plt.legend(fontsize=20)

#plt.savefig('En_stabilization.png',dpi=500, bbox_inches='tight')

# %%
plt.figure(figsize=(10,5))

#plt.xlim(0,1000)

plt.plot(as_sweeps,average_mag_0_7/max(average_mag_0_7)*350-349,'k-',label=r'$\beta =0.7$')
#plt.plot(as_sweeps,average_mag_0_6/max(average_mag_0_6)*100-99,'--',color='k')
#plt.plot(as_sweeps,average_mag_0_5/max(average_mag_0_5)*20-19,'-',color='grey')
#plt.plot(as_sweeps,average_mag_0_5,'-',color='grey')
plt.plot(as_sweeps,average_mag_0_4/max(average_mag_0_4),'-',color='grey',label=r'$\beta=0.4$')
#plt.plot(as_sweeps,average_mag_0_3,'-',color='darkgray',label=r'$\beta=0.3$')
#plt.plot(as_sweeps,average_mag_0_25,'-',color='silver',label=r'$\beta=0.25$')
plt.plot(as_sweeps,average_mag_0_2,'-',color='lightgrey',label=r'$\beta=0.2$')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('MC Sweeps',fontsize=30)
plt.ylabel('Average Magnetization',fontsize=25)

plt.legend(fontsize=20)

#plt.savefig('Mag_stabilization.png',bbox_inches='tight')

# %%
plt.figure(figsize=(10,10))

#plt.xlim(0,1000)

plt.plot(as_sweeps,-average_mag_0_7*(1600/(42*42))+0.1,'kx-',label=r'$\beta =0.7$')
plt.errorbar(as_sweeps,-average_mag_0_7*(1600/(42*42))+0.1, yerr=average_mag_0_7_error, fmt=' ',color='k',capsize=3)



#plt.plot(as_sweeps,average_mag_0_5,'-',color='grey')
plt.plot(as_sweeps,-average_mag_0_4-min(average_mag_0_4),'x-',color='grey',label=r'$\beta=0.4$')
plt.errorbar(as_sweeps,-average_mag_0_4-min(average_mag_0_4),yerr=average_mag_0_4_error, fmt=' ',color='grey',capsize=3)



plt.plot(as_sweeps,-average_mag_0_2,'x--',color='lightgrey',label=r'$\beta=0.2$')
plt.errorbar(as_sweeps,-average_mag_0_2,yerr=average_mag_0_2_error, fmt=' ',color='lightgrey',capsize=3)



plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('MC Sweeps',fontsize=30)
plt.ylabel('Average Magnetization',fontsize=30)

plt.legend(fontsize=20)

plt.savefig('Mag_stabilization.png',dpi=500,bbox_inches='tight')

# %%
plt.plot(as_sweeps,average_mag_0_7/max(average_mag_0_7)*100-99,'k-')
plt.plot(as_sweeps,average_mag_0_6/max(average_mag_0_6),'--',color='k')
plt.plot(as_sweeps,average_mag_0_5/max(average_mag_0_5),'-',color='grey')

# %%
plt.figure(figsize=(10,5))

plt.xlim(0,1000)

plt.plot(as_sweeps,average_mag_0_7/max(average_mag_0_7)*350-349,'k-')
plt.plot(as_sweeps,(average_mag_0_2/max(average_mag_0_2)),'-',color='grey')

# %% [markdown]
# ## Exercise 2&4

# %%
Magn_var1=np.array([np.var(mag1[2000:4000]),np.var(mag09[2000:4000]),
               np.var(mag08[2000:4000]),np.var(mag07[2000:4000]),
               np.var(mag06[2000:4000]),np.var(mag05[2000:4000]),
               np.var(mag0475[2000:4000]),np.var(mag045[7000:10000])])

Magn_var2=np.array([np.mean(mag0425[7000:10000]),
               np.mean(mag04[5000:10000]),np.var(mag03[2000:4000]),
               np.var(mag025[2000:4000]),np.var(mag02[2000:4000])])





T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])

plt.plot(T[0:8],Magn_var1/max(Magn_var2),'kx-')

#plt.plot(np.array([0.425,0.45]),np.array([1,np.var(mag045[7000:10000])])/max(Magn_var2),'kx--')

plt.plot(T[8:],Magn_var2/(max(Magn_var2)),'kx-')

# %%
plt.plot(T,np.concatenate((Magn_var1,Magn_var2))/1600*T)

# %%
Magn=np.array([np.mean(mag1[2000:4000]),np.mean(mag09[2000:4000]),
               np.mean(mag08[2000:4000]),np.mean(mag07[2000:4000]),
               np.mean(mag06[2000:4000]),np.mean(mag05[2000:4000]),
               np.mean(mag0475[2000:4000]),np.mean(mag045[7000:10000]),np.mean(mag0425[7000:10000]),
               np.mean(mag04[5000:10000]),np.mean(mag03[2000:4000]),
               np.mean(mag025[2000:4000]),np.mean(mag02[2000:4000])])

T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])
plt.plot(T,Magn/max(Magn),'x')

# %%
Energie2=np.array([np.mean(energy1[2000:4000]),np.mean(mag09[2000:4000]),
               np.mean(energy08[2000:4000]),np.mean(energy07[2000:4000]),
               np.mean(energy06[2000:4000]),np.mean(energy05[2000:4000]),
               np.mean(energy0475[2000:4000]),np.mean(energy045[7000:10000]),np.mean(mag0425[2000:10000]),
               np.mean(energy04[5000:10000]),np.mean(energy03[2000:4000]),
               np.mean(energy025[2000:4000]),np.mean(energy02[2000:4000])])

T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])
plt.plot(T,Energie2/(max(Energie2)),'x')

# %%
Magn_abs=np.array([np.mean(abs(mag1[2000:4000])),np.mean(abs(mag09[2000:4000])),
               np.mean(abs(mag08[2000:4000])),np.mean(abs(mag07[2000:4000])),
               np.mean(abs(mag06[2000:4000])),np.mean(abs(mag05[2000:4000])),
               np.mean(abs(mag0475[2000:4000])),np.mean(abs(mag045[7000:10000])),np.mean(abs(mag0425[7000:10000])),
               np.mean(abs(mag04[5000:10000])),np.mean(abs(mag03[2000:4000])),
               np.mean(abs(mag025[2000:4000])),np.mean(abs(mag02[2000:4000]))])
T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])
plt.plot(T,Magn/max(Magn),'kx')
plt.plot(T,Magn_abs/max(Magn_abs),'rx')

# %%
Energie=np.array([np.var(energy1[2000:4000]),np.var(mag09[2000:4000]),
               np.var(energy08[2000:4000]),np.var(energy07[2000:4000]),
               np.var(energy06[2000:4000]),np.var(energy05[2000:4000]),
               np.var(energy0475[2000:4000]),np.var(energy045[7000:10000]),np.mean(mag0425[7000:10000]),
               np.var(energy04[5000:10000]),np.var(energy03[2000:4000]),
               np.var(energy025[2000:4000]),np.var(energy02[2000:4000])])

T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])
plt.plot(T,Energie,'x-')

# %%
Energie2=np.array([np.mean(energy1[2000:4000]),np.mean(mag09[2000:4000]),
               np.mean(energy08[2000:4000]),np.mean(energy07[2000:4000]),
               np.mean(energy06[2000:4000]),np.mean(energy05[2000:4000]),
               np.mean(energy0475[2000:4000]),np.mean(energy045[7000:10000]),np.mean(mag0425[2000:10000]),
               np.mean(energy04[5000:10000]),np.mean(energy03[2000:4000]),
               np.mean(energy025[2000:4000]),np.mean(energy02[2000:4000])])

T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])
plt.plot(T,Energie2,'x')

# %%
plt.figure(figsize=(10,5))

forward=np.array([np.mean(Hmag025[2000:4000]),np.mean(Hmag02[2000:4000]),np.mean(Hmag015[2000:4000]),
                  np.mean(Hmag01[2000:4000]),np.mean(Hmag005[2000:4000]),np.mean(Hmag00[2000:4000])])
T_f=np.array([0.25,0.2,0.15,0.1,0.05,0.0])
#plt.plot(T_f,forward)

backward=np.array([np.mean(bHmag01[2000:4000]),np.mean(bHmag015[2000:4000]),np.mean(bHmag026[2000:4000]),
                  np.mean(bHmag04[2000:4000]),np.mean(bHmag05[2000:4000]),np.mean(bHmag065[2000:4000]),
                  np.mean(bHmag09[2000:4000]),np.mean(bHmag2[2000:4000])])
T_b=np.array([0.1,0.15,0.26,0.4,0.5,0.65,0.9,2])
plt.plot(T_b,abs(backward))

backward=np.array([np.mean(bHmag01[2000:4000]),np.mean(bHmag015[2000:4000]),np.mean(bHmag026[2000:4000]),
                  np.mean(bHmag04[2000:4000]),np.mean(bHmag05[2000:4000]),np.mean(bHmag065[2000:4000]),
                  np.mean(bHmag09[2000:4000]),np.mean(bHmag2[2000:4000])])


#back back

#bbackward=np.array([np.mean(bbHmag15[2000:4000]),np.mean(bbHmag1[2000:4000]),np.mean(bbHmag07[2000:4000]),
 #                  np.mean(bbHmag06[2000:4000]),np.mean(bbHmag05[2000:4000]),
  #                  np.mean(bbHmag045[2000:4000]),np.mean(TbbHmag04),
   #                np.mean(bbHmag035[2000:4000]),np.mean(bbHmag03[2000:4000]),np.mean(bbHmag02[2000:4000]),np.mean(bbHmag00[2000:4000])])

bbackward=np.array([np.mean(bbHmag1[2000:4000]),np.mean(bbHmag07[2000:4000]),
                   np.mean(bbHmag06[2000:4000]),np.mean(bbHmag05[2000:4000]),
                    np.mean(bbHmag045[2000:4000]),np.mean(TbbHmag04),
                   np.mean(bbHmag035[2000:4000]),np.mean(bbHmag03[2000:4000]),np.mean(bbHmag02[2000:4000]),np.mean(bbHmag00[2000:4000])])
                
T_bb=np.array([1,0.7,0.6,0.5,0.45,0.4,0.35,0.3,0.2,0.0])

plt.plot(T_bb,bbackward/max(bbackward),'rx')

plt.plot(T,Magn/max(Magn),'x')

# %%
Magn=np.array([np.mean(mag1[2000:4000]),np.mean(mag09[2000:4000]),
               np.mean(mag08[2000:4000]),np.mean(mag07[2000:4000]),
               np.mean(mag06[2000:4000]),np.mean(mag05[2000:4000]),
               np.mean(mag0475[2000:4000]),np.mean(mag045[7000:10000]),np.mean(mag0425[7000:10000]),
               np.mean(mag04[5000:10000]),np.mean(mag03[2000:4000]),
               np.mean(mag025[2000:4000]),np.mean(mag02[2000:4000])])

T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])
plt.plot(T,Magn/max(Magn),'x')

# %%
plt.plot(T_bb,bbackward/max(abs(bbackward)),'rx')
plt.plot(T,Magn/max(abs(Magn)),'x')

# %%
x=np.linspace(start=0,stop=1)

#plt.plot(x,-np.tanh(x))

#p0=[1,1,299,-0.2,0.23]


#plt.plot(x,(1-1*np.sinh(2/(x))**(-4))**(9.0))
plt.plot(T_bb, bbackward/max(abs(bbackward)),'x')



def func(x):
    return (1-np.sinh(x)**(-4))**(1/8)


def fitmag(A,B,C,D,E,x):
    #return A*np.tanh(B*x)+C
    return (A-B*np.sinh(2/(x)*D)**(-4))**C


popt, pcov = curve_fit(fitmag,  T_bb[1:6], bbackward[1:6]/max(abs(bbackward)),maxfev = 100000)


plt.plot(x,fitmag(*popt,x))
# Out:
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/1865843541.py:19: RuntimeWarning: invalid value encountered in power
#   return (A-B*np.sinh(2/(x)*D)**(-4))**C
# /Users/milos/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/1865843541.py:19: RuntimeWarning: divide by zero encountered in true_divide
#   return (A-B*np.sinh(2/(x)*D)**(-4))**C

# %%
plt.figure(figsize=(10,5))

Err_bbackward=np.array([np.var(bbHmag1),np.var(bbHmag07),
                   np.var(bbHmag06),np.var(bbHmag05),
                    np.var(bbHmag045),np.var(TbbHmag04)/3,
                   np.var(bbHmag035),np.var(bbHmag03),np.var(bbHmag02),np.var(bbHmag00)])
                


#plt.plot(T_bb,bbackward/max(abs(bbackward)),'kx')
plt.plot(T_bb,bbackward/max(abs(bbackward-max(bbackward)))-max(bbackward),'kx',label='Data')

plt.errorbar(T_bb,bbackward/max(abs(bbackward-max(bbackward)))-max(bbackward),xerr=0.005*np.ones(len(Err_bbackward)),yerr=Err_bbackward*3, fmt=' ', color='k')

#plt.plot(T_bb[5:],fitmag(*popt,T_bb[5:])/max(abs(bbackward))-5,'r-')
x=np.linspace(start=0.44,stop=1,num=100)

#plt.plot(x,-np.tanh(30*x-13)*0.5-0.5,'r-',label='Fit')

#plt.plot(x,10000*(1.020-1.027*np.sinh(2/x)**(-4))**(0.129)-9999)

plt.plot(x,(1-1*np.sinh(0.47/(x-0.25)+0.23)**(-4))**(899)-1,'r')

#plt.plot(x,fitmag(*popt,x))

plt.axvspan(0.4, 0.5, alpha=0.5, color='yellow')

plt.xlabel(r'Temperature $[1/T_0]$',fontsize=30)

plt.ylabel('Average Magnetization',fontsize=20)

def lin(A,B,x):
    return A*x+B


#x_=np.linspace(start=0.41,stop=0.1,num=10)

#plt.plot(lin(-1000.4,500,x_))

plt.plot(np.array([0.47,0.45])-0.027,np.array([-0.8,-0.5])+0.5,'r',label='fit')

plt.axvline(x=0.425,ls='--',color='k')



plt.legend()


#plt.savefig('fit_mag.png',dpi=400)

# %%
x=np.linspace(start=0.45,stop=0.48,num=100)

#plt.plot(x,(1-1*np.sinh(0.47/(x-0.25)+0.23)**(-4))**(899)-1)


def lin(A,B,x):
    return A*x+B

popt, pcov = curve_fit(lin,  x,(1-1*np.sinh(0.47/(x-0.25)+0.23)**(-4))**(899)-1 ,maxfev = 1000)

plt.plot(lin(*popt,x))

# %%
err_Magn=np.array([np.var(mag1),np.var(mag09),
               np.var(mag08),np.var(mag07),
               np.var(mag06),np.var(mag05),
               np.var(mag0475),np.var(mag045),np.mean(mag0425)/3,
               np.var(mag04),np.var(mag03),
               np.var(mag025),np.var(mag02)])

x=np.linspace(start=0.42,stop=1,num=100)


plt.figure(figsize=(10,5))


plt.xlabel(r'Temperature $[1/T]$',fontsize=30)

plt.ylabel('Average Magnetization',fontsize=20)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.plot(T_bb,bbackward/max(abs(bbackward)),'kx',label='Data')

plt.plot(T,Magn/max(abs(Magn)),'x',color='gray')

#plt.plot(T,Magn*1600/1764,'x')




plt.errorbar(T_bb,bbackward/max(abs(bbackward)),xerr=0.01*np.ones(len(Err_bbackward)),yerr=Err_bbackward*3, fmt=' ', color='k')
plt.errorbar(T,Magn/max(abs(Magn)),xerr=0.01*np.ones(len(Magn)),yerr=err_Magn*3, fmt=' ', color='gray')



plt.axvline(x=0.425,ls='--',color='k')
plt.axvline(x=0.41,ls='--',color='k')

plt.plot(1/(TheoTemp)*0.425,TheoMag,'lightgrey')
plt.plot(1/TheoTemp*0.425,-TheoMag,'lightgrey')


plt.xlim(1.1,0.19)



plt.text(0.43,1.2,r'$T_C$',fontsize='x-large')

plt.text(0.47,-0.4,r'Phase Transition',fontsize='x-large',rotation=90)

plt.axvspan(0.4, 0.475, alpha=0.5, color='yellow')

plt.axvspan(0.425, 0.41, alpha=0.2, color='red')

#plt.savefig('AverageMag.png',bbox_inches='tight')

# %%
plt.plot(1/T_bb*0.425,bbackward/max(abs(bbackward)),'kx',label='Data')

plt.plot(TheoTemp,-TheoMag,'lightgrey')
# Out:
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/1356539283.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1/T_bb*0.425,bbackward/max(abs(bbackward)),'kx',label='Data')

# %%
plt.figure(figsize=(10,5))


plt.xlabel(r'Temperature $[T/T_C]$',fontsize=30)

plt.ylabel(r'Average magnetization $ \langle M \rangle $ ',fontsize=30)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

plt.plot(1/T_bb*0.425,bbackward/max(abs(bbackward)),'kx',label='Data set 1')

plt.plot(1/T*0.425,Magn/max(abs(Magn)),'x',color='gray',label=r'Data set 2 $  \langle\mid M \mid \rangle$')

#plt.plot(T,Magn*1600/1764,'x')




plt.errorbar(1/T_bb*0.425,bbackward/max(abs(bbackward)),xerr=0.01*np.ones(len(Err_bbackward)),yerr=Err_bbackward*3, fmt=' ', color='k')
plt.errorbar(1/T*0.425,Magn/max(abs(Magn)),xerr=0.01*np.ones(len(Magn)),yerr=err_Magn*3, fmt=' ', color='gray')



plt.axvline(x=1,ls='--',color='k')
#plt.axvline(x=1.02,ls='--',color='k')

plt.plot((TheoTemp),TheoMag,'lightgrey',label='Meanfield theory')
plt.plot(TheoTemp,-TheoMag,'lightgrey')


#plt.xlim(1.1,0.19)



plt.text(1,1.2,r'$T_C$',fontsize='x-large')

plt.text(0.9,-0.4,r'Phase Transition',fontsize='x-large',rotation=90)

plt.axvspan(1.0, 0.9, alpha=0.5, color='yellow')

#plt.axvspan(1.02, 1, alpha=0.2, color='red')

plt.legend(fontsize=10)


#plt.savefig('AverageMag.png',bbox_inches='tight')
# Out:
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/3096706523.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1/T_bb*0.425,bbackward/max(abs(bbackward)),'kx',label='Data set 1')
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/3096706523.py:20: RuntimeWarning: divide by zero encountered in true_divide
#   plt.errorbar(1/T_bb*0.425,bbackward/max(abs(bbackward)),xerr=0.01*np.ones(len(Err_bbackward)),yerr=Err_bbackward*3, fmt=' ', color='k')

# %%
plt.figure(figsize=(10,5))


En_bbackward=np.array([np.mean(bHenergy2[2000:4000]),np.mean(bbHenergy15[2000:4000]),
                   np.mean(bbHenergy1[2000:4000]),np.mean(bbHenergy07[2000:4000]),
                    np.mean(bbHenergy05[2000:4000]),np.mean(bbHenergy0475[2000:]),
                   np.mean(bbHenergy045[2000:4000]),np.mean(TbbHenergy04[2000:4000]),
                    np.mean(bbHenergy035[2000:4000]),np.mean(bbHenergy03[2000:4000]),
                    np.mean(bbHenergy02[2000:4000]), np.mean(bbHenergy00[2000:4000])])
err_En_bbackward=np.array([np.var(bHenergy2),np.mean(bbHenergy15),
                   np.var(bbHenergy1),np.var(bbHenergy07),
                    np.var(bbHenergy05),np.var(bbHenergy0475),
                   np.var(bbHenergy045),np.var(TbbHenergy04),
                    np.var(bbHenergy035),np.var(bbHenergy03),
                    np.var(bbHenergy02), np.var(bbHenergy00)])
                
    
t=np.array([2,1.5,1,0.7,0.5,0.475,0.45,0.4,0.35,0.3,0.2,0])

plt.plot(1/t[2:]*0.425,-En_bbackward[2:],'kx',label='Data points J=2')


plt.errorbar(1/t[2:]*0.425,-En_bbackward[2:],xerr=0.01*np.ones(len(En_bbackward[2:])),yerr=err_En_bbackward[2:]*3, fmt=' ', color='k')

plt.errorbar(1/t[2:]*0.425,-En_bbackward[2:]*0.5,xerr=0.01*np.ones(len(En_bbackward[2:])),yerr=err_En_bbackward[2:]*3, fmt=' ', color='c')



#plt.plot(T,Energie2,'x')


plt.xlabel(r'Temperature $[T/T_C]$',fontsize=50)

#plt.ylabel('Average Energy',fontsize=30)
plt.ylabel(r' Enegry per spin $ \langle E/(JN) \rangle $ ',fontsize=30)



plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.plot(1/t[2:]*0.425,-0.5*En_bbackward[2:],'cx',label='Data points J=1')

plt.plot(TheoTemp,Theoenergy,label='Meanfield theory',color='grey')

plt.plot(TheoTemp+0.3,2*Theoenergy,label='Manipulated data J=2',color='lightgrey')



plt.axhline(y=0, color='c', linestyle='--')
#T_theory = np.linspace(0.01,1,100)
#E_theory = np.tanh(1/(T_theory))
#plt.text(0.7,0.2,r'Phase Transition',fontsize='x-large')

plt.axvspan(1.0, 0.9, alpha=0.5, color='yellow')
#plt.plot(T_theory,E_theory)
plt.legend(fontsize=15)

plt.savefig('AverageEnergy.png',bbox_inches='tight')
# Out:
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/2497992435.py:20: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1/t[2:]*0.425,-En_bbackward[2:],'kx',label='Data points J=2')
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/2497992435.py:23: RuntimeWarning: divide by zero encountered in true_divide
#   plt.errorbar(1/t[2:]*0.425,-En_bbackward[2:],xerr=0.01*np.ones(len(En_bbackward[2:])),yerr=err_En_bbackward[2:]*3, fmt=' ', color='k')
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/2497992435.py:25: RuntimeWarning: divide by zero encountered in true_divide
#   plt.errorbar(1/t[2:]*0.425,-En_bbackward[2:]*0.5,xerr=0.01*np.ones(len(En_bbackward[2:])),yerr=err_En_bbackward[2:]*3, fmt=' ', color='c')
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/2497992435.py:41: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
x=np.linspace(start=0,stop=4)

#plt.plot(x,(1-1*np.sinh(0.47/(x-0.25)+0.23)**(-4))**(899)-1)


def lin(A,B,C,x):
    return A*np.tanh(1/(x+1))

popt, pcov = curve_fit(lin, 1/(t[:len(t)-1])*0.425,np.array(En_bbackward[:len(t)-1]) ,maxfev = 1000000)

plt.plot(lin(*popt,1/t)*1.8)
plt.plot( 1/np.array(t),np.array(En_bbackward)/max(En_bbackward))
# Out:
# /Users/milos/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/1287266064.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(lin(*popt,1/t)*1.8)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/1287266064.py:12: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot( 1/np.array(t),np.array(En_bbackward)/max(En_bbackward))

# %%
from scipy import stats
from numpy.random import default_rng
m, k = stats.moment(x, 3), stats.kstat(x, 3)

# %%
plt.figure(figsize=(5,5))


Energie=np.array([np.var(energy1[2000:4000]),np.var(mag09[2000:4000]),
               np.var(energy08[2000:4000]),np.var(energy07[2000:4000]),
               np.var(energy06[2000:4000]),np.var(energy05[2000:4000]),
               np.var(energy0475[2000:4000]),np.var(energy045[7000:10000]),np.mean(mag0425[7000:10000]),
               np.var(energy04[5000:10000]),np.var(energy03[2000:4000]),
               np.var(energy025[2000:4000]),np.var(energy02[2000:4000])])


Energie_error_I=np.array([stats.kstat(energy1[2000:4000],4),stats.kstat(mag09[2000:4000],4),
               stats.kstat(energy08[2000:4000],4),stats.kstat(energy07[2000:4000],4),
               stats.kstat(energy06[2000:4000],4),stats.kstat(energy05[2000:4000],4),
               stats.kstat(energy0475[2000:4000],4),stats.kstat(energy045[7000:10000],4),
                        stats.kstat(mag0425[7000:10000],4),
               stats.kstat(energy04[5000:10000],4),stats.kstat(energy03[2000:4000],4),
               stats.kstat(energy025[2000:4000],4),stats.kstat(energy02[2000:4000],4)])


Energie_error=np.array([stats.kstat(energy1,4),stats.kstat(mag09,4),
               stats.kstat(energy08,4),stats.kstat(energy07,4),
               stats.kstat(energy06,4),stats.kstat(energy05,4),
               stats.kstat(energy0475,4),stats.kstat(energy045,4),
                        stats.kstat(mag0425,4),
               stats.kstat(energy04,4),stats.kstat(energy03,4),
               stats.kstat(energy025,4),stats.kstat(energy02,4)])

T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])
plt.plot((T[:len(Energie)-2]/0.425)**(-1),Energie[:len(Energie)-2]/((T[:len(Energie)-2]/0.425)**(-1))**2*2,'kx-',label='Data points')

plt.plot(TheoTemp,TheoC/3,'c-',label='Meanfield Theory')

plt.legend(fontsize=10,loc=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel(r'Temperature $[T/T_C]$',fontsize=20)
plt.ylabel(r'Heat capacity c',fontsize=20)


plt.savefig('Heatcapacity.png',bbox_inches='tight')

# %%
plt.plot((T[:len(Energie)-3]/0.425)**(-1),Energie[:len(Energie)-3]/(42*42*(T[:len(Energie)-3]/0.425)**(-1))**2*2,'kx-',label='Data points')

# %%
plt.figure(figsize=(5,5))


Magn_Xsi=np.array([np.var(mag1),np.var(mag09),
               np.var(mag08),np.var(mag07),
               np.var(mag06),np.var(mag05),
               np.var(mag0475),np.var(mag045),np.mean(mag0425)/3,
               np.var(mag04),np.var(mag03),
               np.var(mag025),np.var(mag02)])

plt.plot(1/(T)*0.425,Magn_Xsi/max(Magn_Xsi),'kx-',label='Data Points')

plt.plot(TheoTemp,TheoX/max(TheoX),'c--',label='Meanfield Theory')
plt.legend(fontsize=10,loc=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel(r'Temperature $[T/T_C]$',fontsize=20)
plt.ylabel(r'Susceptability $\chi$',fontsize=20)


plt.savefig('Susc.png',bbox_inches='tight')

# %%
from scipy import stats
from numpy.random import default_rng
m, k = stats.moment(x, 3), stats.kstat(x, 3)
rng = default_rng()

x = rng.normal(size=10)

# %%
m, k = stats.moment(x, 3), stats.kstat(x, 3)

# %%
Magn_Xsi_error=np.array([stats.kstat(mag1,4),stats.kstat(mag09,4),
               stats.kstat(mag08,4),stats.kstat(mag07,4),
               stats.kstat(mag06,4),stats.kstat(mag05,4),
               stats.kstat(mag0475,4),stats.kstat(mag045,4),stats.kstat(mag0425,4)/3,
               stats.kstat(mag04,4),stats.kstat(mag03,4),
               stats.kstat(mag025,4),stats.kstat(mag02,4)])

Magn_Xsi=np.array([np.var(mag1),np.var(mag09),
               np.var(mag08),np.var(mag07),
               np.var(mag06),np.var(mag05),
               np.var(mag0475),np.var(mag045),np.mean(mag0425)/3,
               np.var(mag04),np.var(mag03),
               np.var(mag025),np.var(mag02)])

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,5),constrained_layout=True)

#ax1.plot((T[:len(Energie)-3]/0.425)**(-1),Energie[:len(Energie)-3]/((T[:len(Energie)-3]/0.425)**(-1))**2*2,'kx-')
ax1.plot((T/0.425)**(-1),Energie/((T/0.425)**(-1))**2*2,'kx-',label='Data points')


ax1.plot(TheoTemp,TheoC/3,'--',color='grey',label='Meanfield Theory')

#ax1.set_title(r"(a)",fontsize=20)

ax1.set_xlabel(r"Temperature $[1/T_C]$",fontsize=30)
ax1.set_ylabel(r"Heat capacity $[1/k_B]$  ",fontsize=30)
ax1.tick_params(direction='out', length=6, width=2, 
               grid_color='r', grid_alpha=0.5,labelsize=15)
ax1.errorbar((T/0.425)**(-1),Energie/((T/0.425)**(-1))**2*2,yerr=Energie_error,fmt=' ', color='k',capsize=3)

ax1.legend(fontsize=11)






ax2.plot(1/(T)*0.425,Magn_Xsi/(max(Magn_Xsi)),'kx-',label='Data Points')

ax2.plot(TheoTemp,TheoX/max(TheoX),'--',color='grey',label='MFT Theory')



ax2.errorbar(1/(T)*0.425,Magn_Xsi/(max(Magn_Xsi)),yerr=Magn_Xsi_error,fmt=' ', color='k',capsize=3)



ax2.set_xlabel(r"Temperature $[1/T_C]$",fontsize=30)
ax2.set_ylabel(r"Susceptibility $\chi$  ",fontsize=30)
ax2.tick_params(direction='out', length=6, width=2, 
               grid_color='r', grid_alpha=0.5,labelsize=15)
#ax2.set_title(r"(b)",fontsize=20)
ax2.legend(fontsize=14)

fig.savefig('candchi.png',dpi=900,bbox_inches='tight')

# %%
Energie_error
# Out:
# array([ 5.56472726e-09,  8.34255482e-12,  4.97344996e-08,  1.35534130e-07,
#         5.36521956e-07,  7.85207979e-07,  3.84885881e-06,  7.67855334e-05,
#        -4.13326550e-02,  1.47584282e-03,  7.85605401e-04,  6.35443936e-03,
#         9.35803232e-03])

# %%
processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_45.txt'
bbHData045=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData045= pd.DataFrame(bbHData045)

bbHmag045=bbHData045[0]
bbHenergy045=bbHData045[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_4.txt'
bbHData04=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData04= pd.DataFrame(bbHData04)

bbHmag04=bbHData04[0]
bbHenergy04=bbHData04[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_4_T2.txt'
TbbHData04=pd.read_csv(processed_path,sep='\s+',header=None)
TbbHData04= pd.DataFrame(TbbHData04)

TbbHmag04=TbbHData04[0]
TbbHenergy04=TbbHData04[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_35.txt'
bbHData035=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData035= pd.DataFrame(bbHData035)

bbHmag035=bbHData035[0]
bbHenergy035=bbHData035[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_3.txt'
bbHData03=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData03= pd.DataFrame(bbHData03)

bbHmag03=bbHData03[0]
bbHenergy03=bbHData03[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_2.txt'
bbHData02=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData02= pd.DataFrame(bbHData02)

bbHmag02=bbHData02[0]
bbHenergy02=bbHData02[1]

processed_path='/Users/milos/Desktop/Data/Hyst_bb_0_0.txt'
bbHData00=pd.read_csv(processed_path,sep='\s+',header=None)
bbHData00= pd.DataFrame(bbHData00)

bbHmag00=bbHData00[0]
bbHenergy00=bbHData00[1]

# %% [markdown]
# ## Execise 3

# %%
processed_path='/Users/milos/Desktop/Data/Theomess.txt'
Theo=pd.read_csv(processed_path,sep='\s+',header=None)
Theo = pd.DataFrame(Theo)

TheoTemp=Theo[0]

TheoMag=Theo[1]

Theoenergy=Theo[2]

TheoC=Theo[3]

TheoX=Theo[4]

# %%
plt.plot(TheoTemp,TheoMag-1)

plt.plot(T_bb/0.425,bbackward/max(abs(bbackward))-max(bbackward),'rx')

# %%
plt.figure(figsize=(5,5))

plt.plot(TheoTemp,TheoMag,'b')
plt.plot(TheoTemp,-TheoMag,'g')

x_erro=(np.ones(len(Err_bbackward))*0.01)**(-1)

plt.errorbar((T_bb/0.425)**(-1),sorted(bbackward/max(abs(bbackward))),xerr=0.05*np.ones(len(Err_bbackward)),yerr=sorted(Err_bbackward), fmt=' ', color='k')
plt.errorbar((T/0.425)**(-1),(Magn/max(abs(Magn))),xerr=0.05*np.ones(len(Magn)),yerr=(err_Magn), fmt=' ', color='k')


plt.plot((T/0.425)**(-1),(Magn/max(abs(Magn))),'x')
plt.plot((T_bb/0.425)**(-1),sorted(bbackward/max(abs(bbackward))),'rx')
# Out:
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/3670290802.py:8: RuntimeWarning: divide by zero encountered in reciprocal
#   plt.errorbar((T_bb/0.425)**(-1),sorted(bbackward/max(abs(bbackward))),xerr=0.05*np.ones(len(Err_bbackward)),yerr=sorted(Err_bbackward), fmt=' ', color='k')
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/3670290802.py:13: RuntimeWarning: divide by zero encountered in reciprocal
#   plt.plot((T_bb/0.425)**(-1),sorted(bbackward/max(abs(bbackward))),'rx')

# %%
plt.plot(TheoTemp,abs(TheoMag-1))
plt.plot(TheoTemp,(TheoMag-1))
plt.plot(T_bb/0.425,abs(bbackward/max(abs(bbackward))-max(bbackward)),'rx')
plt.plot(T_bb/0.425,bbackward/max(abs(bbackward))-max(bbackward),'rx')

# %%
plt.figure(figsize=(5,5))

plt.plot(TheoTemp,Theoenergy)

plt.plot(t[2:]/0.425,En_bbackward[2:]-2,'kx')

# %%
plt.figure(figsize=(5,5))


Energie=np.array([np.var(energy1[2000:4000]),np.var(mag09[2000:4000]),
               np.var(energy08[2000:4000]),np.var(energy07[2000:4000]),
               np.var(energy06[2000:4000]),np.var(energy05[2000:4000]),
               np.var(energy0475[2000:4000]),np.var(energy045[7000:10000]),np.mean(mag0425[7000:10000]),
               np.var(energy04[5000:10000]),np.var(energy03[2000:4000]),
               np.var(energy025[2000:4000]),np.var(energy02[2000:4000])])

T=np.array([1,0.9,0.8,0.7,0.6,0.5,0.475,0.45,0.425,0.4,0.3,0.25,0.2])
plt.plot((T[:len(Energie)-3]/0.425)**(-1),Energie[:len(Energie)-3]/((T[:len(Energie)-3]/0.425)**(-1))**2*2,'x-')

plt.plot(TheoTemp,TheoC/3)

# %%
plt.plot((T[:len(Energie)-3]/0.425)**(-1),Energie[:len(Energie)-3]/((T[:len(Energie)-3]/0.425)**(-1))**2*2,'x-')

# %%
Magn_Xsi=np.array([np.var(mag1),np.var(mag09),
               np.var(mag08),np.var(mag07),
               np.var(mag06),np.var(mag05),
               np.var(mag0475),np.var(mag045),np.mean(mag0425)/3,
               np.var(mag04),np.var(mag03),
               np.var(mag025),np.var(mag02)])

plt.plot(1/(T)*0.425,Magn_Xsi/max(Magn_Xsi))

plt.plot(TheoTemp,TheoX/max(TheoX))

# %% [markdown]
# \underline{Entropie}

# %%
processed_path='/Users/milos/Desktop/Data/Entropie/S_0_2.txt'
Entro_0_2=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_2 = pd.DataFrame(Entro_0_2)

Entropy_0_2=Entro_0_2[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_0_3.txt'
Entro_0_3=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_3 = pd.DataFrame(Entro_0_3)

Entropy_0_3=Entro_0_3[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_0_4.txt'
Entro_0_4=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_4 = pd.DataFrame(Entro_0_4)

Entropy_0_4=Entro_0_4[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_0_425.txt'
Entro_0_425=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_425 = pd.DataFrame(Entro_0_425)

Entropy_0_425=Entro_0_425[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_0_5.txt'
Entro_0_5=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_5 = pd.DataFrame(Entro_0_5)

Entropy_0_5=Entro_0_5[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_0_6.txt'
Entro_0_6=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_6 = pd.DataFrame(Entro_0_6)

Entropy_0_6=Entro_0_6[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_0_7.txt'
Entro_0_7=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_7 = pd.DataFrame(Entro_0_7)

Entropy_0_7=Entro_0_7[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_0_8.txt'
Entro_0_8=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_8 = pd.DataFrame(Entro_0_8)

Entropy_0_8=Entro_0_8[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_0_9.txt'
Entro_0_9=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_0_9 = pd.DataFrame(Entro_0_9)

Entropy_0_9=Entro_0_9[0]

processed_path='/Users/milos/Desktop/Data/Entropie/S_1_0.txt'
Entro_1_0=pd.read_csv(processed_path,sep='\s+',header=None)
Entro_1_0 = pd.DataFrame(Entro_1_0)

Entropy_1_0=Entro_1_0[0]

# %%
S=np.array([S0,S1,S2,S3,S4,S5,S6,S7,S8,S9])

# %%
plt.figure(figsize=(10,5))

Temperature=np.array([1,0.9,0.8,0.7,0.6,0.5,0.425,0.4,0.3,0.2])

S_entropy=np.array([np.mean(Entropy_1_0[4000:]),np.mean(Entropy_0_9[4000:]),np.mean(Entropy_0_8[4000:]),np.mean(Entropy_0_7[4000:]),
            np.mean(Entropy_0_6[4000:]),
           np.mean(Entropy_0_5[4000:]),np.mean(Entropy_0_425[4000:]),np.mean(Entropy_0_4[4000:]),
            np.mean(Entropy_0_3[4000:]),np.mean(Entropy_0_2[4000:])])

S_entropy_err=np.array([np.var(Entropy_1_0),np.var(Entropy_0_9),np.var(Entropy_0_8),np.var(Entropy_0_7),
            np.var(Entropy_0_6),np.var(Entropy_0_5),np.var(Entropy_0_425),np.var(Entropy_0_4),
            np.var(Entropy_0_3),np.var(Entropy_0_2)])


S0=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[0]/100)))*np.math.factorial(round(abs(16-S_entropy[0]/100))))
S1=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[1]/100)))*np.math.factorial(round(abs(16-S_entropy[1]/100))))
S2=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[2]/100)))*np.math.factorial(round(abs(16-S_entropy[2]/100))))
S3=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[3]/100)))*np.math.factorial(round(abs(16-S_entropy[3]/100))))
S4=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[4]/100)))*np.math.factorial(round(abs(16-S_entropy[4]/100))))
S5=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[5]/100)))*np.math.factorial(round(abs(16-S_entropy[5]/100))))
S6=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[6]/100)))*np.math.factorial(round(abs(16-S_entropy[6]/100))))
S7=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[7]/100)))*np.math.factorial(round(abs(16-S_entropy[7]/100))))
S8=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[8]/100)))*np.math.factorial(round(abs(16-S_entropy[8]/100))))
S9=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[9]/100)))*np.math.factorial(round(abs(16-S_entropy[9]/100))))


plt.errorbar((1/Temperature*0.425),abs(np.log(S)),xerr=0.01*np.ones(len(En_bbackward[2:])),yerr=np.log(S_entropy_err), fmt=' ', color='k',capsize=3)



S=np.array([S0,S1,S2,S3,S4,S5,S6,S7,S8,S9])


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)


plt.xlabel(r'Temperature $[T/T_C]$',fontsize=30)

plt.ylabel(r'Entropy $[1/k_B]$',fontsize=30)




#plt.plot(sorted(1/Temperature*0.425),sorted(abs(np.log(S))),'x')

plt.plot((1/Temperature*0.425),(abs(np.log(S))),'kx',label='Data Points')


plt.legend(fontsize=20,loc=4)


#plt.text(1,1.2,r'$T_C$',fontsize='x-large')

plt.text(0.92,30,r'Phase Transition',fontsize='x-large',rotation=90)

plt.axvspan(1.05, 0.9, alpha=0.5, color='yellow')

#plt.axvspan(1.02, 1, alpha=0.2, color='red')

#plt.savefig('Entropy.png',bbox_inches='tight')

# %%
np.math.factorial(round(1.6))
# Out:
# 2

# %%
S0=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[0]/100)))*np.math.factorial(round(abs(16-S_entropy[0]/100))))

# %%
plt.figure(figsize=(10,5))

Temperature=np.array([1,0.9,0.8,0.7,0.6,0.5,0.425,0.4,0.3,0.2])

S_entropy=np.array([np.mean(Entropy_1_0[4000:]),np.mean(Entropy_0_9[4000:]),np.mean(Entropy_0_8[4000:]),np.mean(Entropy_0_7[4000:]),
            np.mean(Entropy_0_6[4000:]),
           np.mean(Entropy_0_5[4000:]),np.mean(Entropy_0_425[4000:]),np.mean(Entropy_0_4[4000:]),
            np.mean(Entropy_0_3[4000:]),np.mean(Entropy_0_2[4000:])])

S_entropy_err=np.array([np.var(Entropy_1_0),np.var(Entropy_0_9),np.var(Entropy_0_8),np.var(Entropy_0_7),
            np.var(Entropy_0_6),np.var(Entropy_0_5),np.var(Entropy_0_425),np.var(Entropy_0_4),
            np.var(Entropy_0_3),np.var(Entropy_0_2)])


S0=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[0]/100)))*np.math.factorial(round(abs(16-S_entropy[0]/100))))
S1=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[1]/100)))*np.math.factorial(round(abs(16-S_entropy[1]/100))))
S2=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[2]/100)))*np.math.factorial(round(abs(16-S_entropy[2]/100))))
S3=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[3]/100)))*np.math.factorial(round(abs(16-S_entropy[3]/100))))
S4=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[4]/100)))*np.math.factorial(round(abs(16-S_entropy[4]/100))))
S5=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[5]/100)))*np.math.factorial(round(abs(16-S_entropy[5]/100))))
S6=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[6]/100)))*np.math.factorial(round(abs(16-S_entropy[6]/100))))
S7=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[7]/100)))*np.math.factorial(round(abs(16-S_entropy[7]/100))))
S8=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[8]/100)))*np.math.factorial(round(abs(16-S_entropy[8]/100))))
S9=np.math.factorial(round(1.6))/(np.math.factorial(round(abs(S_entropy[9]/100)))*np.math.factorial(round(abs(16-S_entropy[9]/100))))


plt.errorbar((1/Temperature*0.425),abs(np.log(S)),xerr=0.01*np.ones(len(En_bbackward[2:])),yerr=np.log(S_entropy_err), fmt=' ', color='k',capsize=3)



S=np.array([S0,S1,S2,S3,S4,S5,S6,S7,S8,S9])


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)


plt.xlabel(r'Temperature $[T/T_C]$',fontsize=30)

plt.ylabel('Dimesnionsless Entropy S',fontsize=20)




#plt.plot(sorted(1/Temperature*0.425),sorted(abs(np.log(S))),'x')

plt.plot((1/Temperature*0.425),((np.log(S*100000))),'kx',label='Data Points')


plt.legend(fontsize=20,loc=4)


#plt.text(1,1.2,r'$T_C$',fontsize='x-large')

plt.text(0.92,30,r'Phase Transition',fontsize='x-large',rotation=90)

plt.axvspan(1.05, 0.9, alpha=0.5, color='yellow')

#plt.axvspan(1.02, 1, alpha=0.2, color='red')

#plt.savefig('Entropy.png',bbox_inches='tight')

# %%
round(abs(S_entropy[0]/100))
# Out:
# 2

# %%
processed_path='/Users/milos/Desktop/Data/Correl/0_1_correl.txt'
correl01=pd.read_csv(processed_path,sep='\s+',header=None)
correl01 = pd.DataFrame(correl01)

_01cor1=correl01[0]
_01cor2=correl01[1]
_01cor5=correl01[2]
_01cor10=correl01[3]
_01cor20=correl01[4]
_01cor40=correl01[5]


processed_path='/Users/milos/Desktop/Data/Correl/0_2_correl.txt'
correl02=pd.read_csv(processed_path,sep='\s+',header=None)
correl02 = pd.DataFrame(correl02)

_02cor1=correl02[0]
_02cor2=correl02[1]
_02cor5=correl02[2]
_02cor10=correl02[3]
_02cor20=correl02[4]
_02cor40=correl02[5]


processed_path='/Users/milos/Desktop/Data/Correl/0_3_correl.txt'
correl03=pd.read_csv(processed_path,sep='\s+',header=None)
correl03 = pd.DataFrame(correl03)

_03cor1=correl03[0]
_03cor2=correl03[1]
_03cor5=correl03[2]
_03cor10=correl03[3]
_03cor20=correl03[4]
_03cor40=correl03[5]


processed_path='/Users/milos/Desktop/Data/Correl/0_4_correl.txt'
correl04=pd.read_csv(processed_path,sep='\s+',header=None)
correl04 = pd.DataFrame(correl04)

_04cor1=correl04[0]
_04cor2=correl04[1]
_04cor5=correl04[2]
_04cor10=correl04[3]
_04cor20=correl04[4]
_04cor40=correl04[5]



processed_path='/Users/milos/Desktop/Data/Correl/0_425_correl.txt'
correl0425=pd.read_csv(processed_path,sep='\s+',header=None)
correl0425 = pd.DataFrame(correl0425)

_0425cor1=correl0425[0]
_0425cor2=correl0425[1]
_0425cor5=correl0425[2]
_0425cor10=correl0425[3]
_0425cor20=correl0425[4]
_0425cor40=correl0425[5]


processed_path='/Users/milos/Desktop/Data/Correl/0_45_correl.txt'
correl045=pd.read_csv(processed_path,sep='\s+',header=None)
correl045 = pd.DataFrame(correl045)

_045cor1=correl045[0]
_045cor2=correl045[1]
_045cor5=correl045[2]
_045cor10=correl045[3]
_045cor20=correl045[4]
_045cor40=correl045[5]


processed_path='/Users/milos/Desktop/Data/Correl/0_5_correl.txt'
correl05=pd.read_csv(processed_path,sep='\s+',header=None)
correl05 = pd.DataFrame(correl05)

_05cor1=correl05[0]
_05cor2=correl05[1]
_05cor5=correl05[2]
_05cor10=correl05[3]
_05cor20=correl05[4]
_05cor40=correl05[5]


processed_path='/Users/milos/Desktop/Data/Correl/0_6_correl.txt'
correl06=pd.read_csv(processed_path,sep='\s+',header=None)
correl06 = pd.DataFrame(correl06)

_06cor1=correl06[0]
_06cor2=correl06[1]
_06cor5=correl06[2]
_06cor10=correl06[3]
_06cor20=correl06[4]
_06cor40=correl06[5]

processed_path='/Users/milos/Desktop/Data/Correl/0_7_correl.txt'
correl07=pd.read_csv(processed_path,sep='\s+',header=None)
correl07 = pd.DataFrame(correl07)

_07cor1=correl07[0]
_07cor2=correl07[1]
_07cor5=correl07[2]
_07cor10=correl07[3]
_07cor20=correl07[4]
_07cor40=correl07[5]


processed_path='/Users/milos/Desktop/Data/Correl/0_8_correl.txt'
correl08=pd.read_csv(processed_path,sep='\s+',header=None)
correl08 = pd.DataFrame(correl08)

_08cor1=correl08[0]
_08cor2=correl08[1]
_08cor5=correl08[2]
_08cor10=correl08[3]
_08cor20=correl08[4]
_08cor40=correl08[5]


processed_path='/Users/milos/Desktop/Data/Correl/1_0_correl.txt'
correl1=pd.read_csv(processed_path,sep='\s+',header=None)
correl1 = pd.DataFrame(correl1)

_1cor1=correl1[0]
_1cor2=correl1[1]
_1cor5=correl1[2]
_1cor10=correl1[3]
_1cor20=correl1[4]
_1cor40=correl1[5]

# %%
correl01=np.array([np.mean(_01cor1[2000:]),np.mean(_01cor2[2000:]),np.mean(_01cor5[2000:]),
                  np.mean(_01cor10[2000:]),np.mean(_01cor20[2000:]),np.mean(_01cor40[2000:])])

correl02=np.array([np.mean(_02cor1[2000:]),np.mean(_02cor2[2000:]),np.mean(_02cor5[2000:]),
                  np.mean(_02cor10[2000:]),np.mean(_02cor20[2000:]),np.mean(_02cor40[2000:])])

correl02_err=np.array([np.var(_02cor1[2000:]),np.var(_02cor2[2000:]),np.var(_02cor5[2000:]),
                  np.var(_02cor10[2000:]),np.var(_02cor20[2000:]),np.var(_02cor40[2000:])])




correl03=np.array([np.mean(_03cor1[2000:]),np.mean(_03cor2[2000:]),np.mean(_03cor5[2000:]),
                  np.mean(_03cor10[2000:]),np.mean(_03cor20[2000:]),np.mean(_03cor40[2000:])])

correl04=np.array([np.mean(_04cor1[2000:]),np.mean(_04cor2[2000:]),np.mean(_04cor5[2000:]),
                  np.mean(_04cor10[2000:]),np.mean(_04cor20[2000:]),np.mean(_04cor40[2000:])])



correl0425=np.array([np.mean(_0425cor1[2000:]),np.mean(_0425cor2[2000:]),np.mean(_0425cor5[2000:]),
                  np.mean(_0425cor10[2000:]),np.mean(_0425cor20[2000:]),np.mean(_0425cor40[2000:])])
correl0425_err=np.array([np.var(_0425cor1[2000:]),np.var(_0425cor2[2000:]),np.var(_0425cor5[2000:]),
                  np.var(_0425cor10[2000:]),np.var(_0425cor20[2000:]),np.var(_0425cor40[2000:])])

correl045=np.array([np.mean(_045cor1[2000:]),np.mean(_045cor2[2000:]),np.mean(_045cor5[2000:]),
                  np.mean(_045cor10[2000:]),np.mean(_045cor20[2000:]),np.mean(_045cor40[2000:])])
correl045_err=np.array([np.var(_045cor1[2000:]),np.var(_045cor2[2000:]),np.var(_045cor5[2000:]),
                  np.var(_045cor10[2000:]),np.var(_045cor20[2000:]),np.var(_045cor40[2000:])])

correl05=np.array([np.mean(_05cor1[2000:]),np.mean(_05cor2[2000:]),np.mean(_05cor5[2000:]),
                  np.mean(_05cor10[2000:]),np.mean(_05cor20[2000:]),np.mean(_05cor40[2000:])])

correl06=np.array([np.mean(_06cor1[2000:]),np.mean(_06cor2[2000:]),np.mean(_06cor5[2000:]),
                  np.mean(_06cor10[2000:]),np.mean(_06cor20[2000:]),np.mean(_06cor40[2000:])])

correl07=np.array([np.mean(_07cor1[2000:]),np.mean(_07cor2[2000:]),np.mean(_07cor5[2000:]),
                  np.mean(_07cor10[2000:]),np.mean(_07cor20[2000:]),np.mean(_07cor40[2000:])])

correl08=np.array([np.mean(_08cor1[2000:]),np.mean(_08cor2[2000:]),np.mean(_08cor5[2000:]),
                  np.mean(_08cor10[2000:]),np.mean(_08cor20[2000:]),np.mean(_08cor40[2000:])])






correl1=np.array([np.mean(_1cor1[2000:]),np.mean(_1cor2[2000:]),np.mean(_1cor5[2000:]),
                  np.mean(_1cor10[2000:]),np.mean(_1cor20[2000:]),np.mean(_1cor40[2000:])])

correl1_err=np.array([np.var(_1cor1[2000:]),np.var(_1cor2[2000:]),np.var(_1cor5[2000:]),
                  np.var(_1cor10[2000:]),np.var(_1cor20[2000:]),np.var(_1cor40[2000:])])

# %%
d=np.array([1,2,5,10,20,40])



plt.figure(figsize=(20,10))

#plt.plot(d,correl01/(max(correl01)))
plt.plot(d,correl02/max(correl02),'x-',color='lightgrey',label=r'$\beta=0.2$')
plt.errorbar(d,correl02/max(correl02),yerr=correl02_err/max(correl02_err), fmt=' ', color='lightgrey',capsize=3)



#plt.plot(d,correl03/max(correl03))
#plt.plot(d,correl04/max(correl04))
plt.plot(d,correl0425/max(correl0425),'rx-',label=r'$\beta=0.425$')
plt.errorbar(d,correl0425/max(correl0425),yerr=correl0425_err/max(correl0425_err), fmt=' ', color='r',capsize=3)




plt.plot(d,correl045/max(correl045),'x-',color='grey',label=r'$\beta=0.45$')
plt.errorbar(d,correl045/max(correl045),yerr=correl045_err/max(correl045_err), fmt=' ', color='grey',capsize=3)



plt.plot(d,correl1/max(correl1),'kx-',label=r'$\beta=1.0$')
plt.errorbar(d,correl1/max(correl1),yerr=correl1_err/max(correl1_err), fmt=' ', color='grey',capsize=3)



#plt.xlim(1,10)

plt.legend(fontsize=40);




#plt.errorbar((1/Temperature*0.425),abs(np.log(S)),xerr=0.01*np.ones(len(En_bbackward[2:])),yerr=np.log(S_entropy_err), fmt=' ', color='k',capsize=3)



plt.ylim(-0.5,1.2)


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)


plt.xlabel(r'Lattice distance d',fontsize=30)

plt.ylabel(r'Correlation function $G_{ij}$',fontsize=30)


plt.legend(fontsize=20);

#plt.savefig('longcorrel.png',dpi=400)

# %%
plt.plot(d,correl08/max(correl08))
plt.plot(d,correl1/max(correl1))
plt.plot(d,correl07/max(correl07),'c-',label=r'$\beta=0.7$')

# %%
processed_path='/Users/milos/Desktop/Data/Correl/0_1_correl2.txt'
correl01=pd.read_csv(processed_path,sep='\s+',header=None)
correl01 = pd.DataFrame(correl01)

_01cor1=correl01[0]
_01cor2=correl01[1]
_01cor5=correl01[2]
_01cor10=correl01[3]
_01cor20=correl01[4]
_01cor40=correl01[5]

processed_path='/Users/milos/Desktop/Data/Correl/0_2_correl2.txt'
correl02=pd.read_csv(processed_path,sep='\s+',header=None)
correl02 = pd.DataFrame(correl02)

_02cor1=correl02[0]
_02cor2=correl02[1]
_02cor5=correl02[2]
_02cor10=correl02[3]
_02cor20=correl02[4]
_02cor40=correl02[5]

processed_path='/Users/milos/Desktop/Data/Correl/0_3_correl2.txt'
correl03=pd.read_csv(processed_path,sep='\s+',header=None)
correl03 = pd.DataFrame(correl03)

_03cor1=correl03[0]
_03cor2=correl03[1]
_03cor5=correl03[2]
_03cor10=correl03[3]
_03cor20=correl03[4]
_03cor40=correl03[5]

processed_path='/Users/milos/Desktop/Data/Correl/0_425_correl2.txt'
correl0425=pd.read_csv(processed_path,sep='\s+',header=None)
correl0425 = pd.DataFrame(correl0425)

_0425cor1=correl0425[0]
_0425cor2=correl0425[1]
_0425cor5=correl0425[2]
_0425cor10=correl0425[3]
_0425cor20=correl0425[4]
_0425cor40=correl0425[5]

processed_path='/Users/milos/Desktop/Data/Correl/0_65_correl2.txt'
correl065=pd.read_csv(processed_path,sep='\s+',header=None)
correl065 = pd.DataFrame(correl065)

_065cor1=correl065[0]
_065cor2=correl065[1]
_065cor5=correl065[2]
_065cor10=correl065[3]
_065cor20=correl065[4]
_065cor40=correl065[5]



processed_path='/Users/milos/Desktop/Data/Correl/0_8_correl2.txt'
correl08=pd.read_csv(processed_path,sep='\s+',header=None)
correl08 = pd.DataFrame(correl08)

_08cor1=correl08[0]
_08cor2=correl08[1]
_08cor5=correl08[2]
_08cor10=correl08[3]
_08cor20=correl08[4]
_08cor40=correl08[5]

# %%
correl01=np.array([np.mean(_01cor1[2000:]),np.mean(_01cor2[2000:]),np.mean(_01cor5[2000:]),
                  np.mean(_01cor10[2000:]),np.mean(_01cor20[2000:]),np.mean(_01cor40[2000:])])

correl02=np.array([np.mean(_02cor1[2000:]),np.mean(_02cor2[2000:]),np.mean(_02cor5[2000:]),
                  np.mean(_02cor10[2000:]),np.mean(_02cor20[2000:]),np.mean(_02cor40[2000:])])

correl03=np.array([np.mean(_03cor1[2000:]),np.mean(_03cor2[2000:]),np.mean(_03cor5[2000:]),
                  np.mean(_03cor10[2000:]),np.mean(_03cor20[2000:]),np.mean(_03cor40[2000:])])


correl0425=np.array([np.mean(_0425cor1[2000:]),np.mean(_0425cor2[2000:]),np.mean(_0425cor5[2000:]),
                  np.mean(_0425cor10[2000:]),np.mean(_0425cor20[2000:]),np.mean(_0425cor40[2000:])])

correl065=np.array([np.mean(_065cor1[2000:]),np.mean(_065cor2[2000:]),np.mean(_065cor5[2000:]),
                  np.mean(_065cor10[2000:]),np.mean(_065cor20[2000:]),np.mean(_065cor40[2000:])])


correl08=np.array([np.mean(_08cor1[2000:]),np.mean(_08cor2[2000:]),np.mean(_08cor5[2000:]),
                  np.mean(_08cor10[2000:]),np.mean(_08cor20[2000:]),np.mean(_08cor40[2000:])])

# %%
d2=np.array([2,3,4,5,6,10])

plt.figure(figsize=(10,5))

#plt.plot(d2,correl01/max(correl01),'x-',color='b',label=r'$\beta=0.2$')

plt.plot(d2,correl02/max(correl02),'x-',color='gray',label=r'$\beta=0.2$')

plt.plot(d2,correl03/max(correl03),'x-',color='darkgray',label=r'$\beta=0.2$')

plt.plot(d2,correl0425/max(correl0425),'kx-',label=r'$\beta=0.425$')

plt.plot(d2,correl065/max(correl065),'x-',color='b',label=r'$\beta=0.2$')


plt.plot(d2,correl08/max(correl08),'x-',color='lightgray',label=r'$\beta=0.2$')

# %%
plt.plot(d2,correl08/max(correl08),'x-',color='lightgray',label=r'$\beta=0.2$')

plt.plot(d2,correl065/max(correl065),'x-',color='b',label=r'$\beta=0.2$')

# %% [markdown]
# ## All neigbours of two pairs

# %%
processed_path='/Users/milos/Desktop/Data/Correl/0_2_correl_NN.txt'
correl02NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl02NN = pd.DataFrame(correl02NN)

_02corNN=correl02NN[6]


processed_path='/Users/milos/Desktop/Data/Correl/0_3_correl_NN.txt'
correl03NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl03NN = pd.DataFrame(correl03NN)

_03corNN=correl03NN[6]


processed_path='/Users/milos/Desktop/Data/Correl/0_4_correl_NN.txt'
correl04NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl04NN = pd.DataFrame(correl04NN)

_04corNN=correl04NN[6]

processed_path='/Users/milos/Desktop/Data/Correl/0_425_correl_NN.txt'
correl0425NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl0425NN = pd.DataFrame(correl0425NN)

_0425corNN=correl0425NN[0]


processed_path='/Users/milos/Desktop/Data/Correl/0_45_correl_NN.txt'
correl045NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl045NN = pd.DataFrame(correl045NN)

_045corNN=correl045NN[6]

processed_path='/Users/milos/Desktop/Data/Correl/0_5_correl_NN.txt'
correl05NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl05NN = pd.DataFrame(correl05NN)

_05corNN=correl05NN[0]

processed_path='/Users/milos/Desktop/Data/Correl/0_6_correl_NN.txt'
correl06NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl06NN = pd.DataFrame(correl06NN)

_06corNN=correl06NN[0]

processed_path='/Users/milos/Desktop/Data/Correl/0_7_correl_NN.txt'
correl07NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl07NN = pd.DataFrame(correl07NN)

_07corNN=correl07NN[0]

processed_path='/Users/milos/Desktop/Data/Correl/0_8_correl_NN.txt'
correl08NN=pd.read_csv(processed_path,sep='\s+',header=None)
correl08NN = pd.DataFrame(correl08NN)

_08corNN=correl08NN[0]

# %%
pair_correlation=np.array([np.mean(_02corNN[2000:]),np.mean(_03corNN[2000:]),np.mean(_04corNN[2000:]),np.mean(_0425corNN[2000:]),
                  np.mean(_045cor1[2000:]),np.mean(_05cor1[2000:]),np.mean(_05cor1[2000:]),
                           np.mean(_06cor1[2000:]),np.mean(_07cor1[2000:]),np.mean(_08cor1[2000:])])

pair_correlation_errpr=np.array([np.var(_02corNN[2000:]),np.var(_03corNN[2000:]),np.var(_04corNN[2000:]),np.var(_0425corNN[2000:]),
                  np.var(_045cor1[2000:]),np.var(_05cor1[2000:]),np.var(_05cor1[2000:]),
                           np.var(_06cor1[2000:]),np.var(_07cor1[2000:]),np.var(_08cor1[2000:])])

# %%
correl02_error=np.array([np.var(_02cor1[2000:]),np.var(_02cor2[2000:]),np.var(_02cor5[2000:]),
                  np.var(_02cor10[2000:]),np.var(_02cor20[2000:]),np.var(_02cor40[2000:])])

correl03_error=np.array([np.var(_03cor1[2000:]),np.var(_03cor2[2000:]),np.var(_03cor5[2000:]),
                  np.var(_03cor10[2000:]),np.var(_03cor20[2000:]),np.var(_03cor40[2000:])])


correl0425_error=np.array([np.var(_0425cor1[2000:]),np.var(_0425cor2[2000:]),np.var(_0425cor5[2000:]),
                  np.var(_0425cor10[2000:]),np.var(_0425cor20[2000:]),np.var(_0425cor40[2000:])])

correl065_error=np.array([np.var(_065cor1[2000:]),np.var(_065cor2[2000:]),np.var(_065cor5[2000:]),
                  np.var(_065cor10[2000:]),np.var(_065cor20[2000:]),np.var(_065cor40[2000:])])


correl08_error=np.array([np.var(_08cor1[2000:]),np.var(_08cor2[2000:]),np.var(_08cor5[2000:]),
                  np.var(_08cor10[2000:]),np.var(_08cor20[2000:]),np.var(_08cor40[2000:])])

# %%
neigbouring_pairs=np.array([np.mean(_01cor1[2000:]),np.mean(_02cor1[2000:]),np.mean(_03cor1[2000:]),np.mean(_04cor1[2000:]),
                  np.mean(_0425cor1[2000:]),np.mean(_045cor1[2000:]),np.mean(_05cor1[2000:]),
                           np.mean(_06cor1[2000:]),np.mean(_07cor1[2000:]),np.mean(_08cor1[2000:])])

neigbouring_pairs_error=np.array([np.var(_01cor1[2000:]),np.var(_02cor1[2000:]),np.var(_03cor1[2000:]),np.var(_04cor1[2000:]),
                  np.var(_0425cor1[2000:]),np.var(_045cor1[2000:]),np.var(_05cor1[2000:]),
                           np.mean(_06cor1[2000:]),np.var(_07cor1[2000:]),np.var(_08cor1[2000:])])




t_nn=np.array([0.1,0.2,0.3,0.4,0.425,0.45,0.5,0.6,0.7,0.8])

plt.plot(t_nn,neigbouring_pairs)


plt.plot(t_nn,pair_correlation,'x-')

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,5))


ax1.plot(d2,correl02/max(correl02),'x-',color='gray',label=r'$\beta=0.2$')
ax1.errorbar(d2,correl02/max(correl02),yerr=correl02_error/10, fmt=' ',color='gray',capsize=3)

ax1.plot(d2,correl03/max(correl03),'x-',color='darkgray',label=r'$\beta=0.3$')
ax1.errorbar(d2,correl03/max(correl03),yerr=correl03_error/10, fmt=' ',color='darkgray',capsize=3)

ax1.plot(d2,correl0425/max(correl0425),'kx-',label=r'$\beta=0.425$')
ax1.errorbar(d2,correl0425/max(correl0425),yerr=correl0425_error/10, fmt=' ',color='k',capsize=3)

ax1.plot(d2,correl065/max(correl065),'x-',color='b',label=r'$\beta=0.65$')
ax1.errorbar(d2,correl065/max(correl065),yerr=correl065_error, fmt=' ',color='b',capsize=3)

ax1.plot(d2,correl08/max(correl08),'x--',color='lightgray',label=r'$\beta=0.8$')
ax1.errorbar(d2,correl08/max(correl08),yerr=correl08_error, fmt=' ',color='lightgray',capsize=3)

ax1.set_title(r"(a)",fontsize=20)

ax1.set_xlabel(r"Lattisce distance",fontsize=20)
ax1.set_ylabel(r"Correlation function $G_{ij}=\langle s_is_j \rangle$  ",fontsize=17)
ax1.set_xticklabels(d2, fontsize= 15)
#ax1.set_yticklabels(correl08, fontsize= 15)
ax1.legend(bbox_to_anchor=(2.6,0.8))

ax1.tick_params(direction='out', length=6, width=2, 
               grid_color='r', grid_alpha=0.5,labelsize=15)

#ax2.set_title(r"(b)",fontsize=20)

ax2.set_xlabel(r"Temperature $[1/\beta]$",fontsize=20)
#ax2.set_ylabel(r"Correlation function $G_{ij}=\langle s_is_j \rangle$  ",fontsize=15)



ax2.plot(t_nn,pair_correlation,'x-',color='grey',label='Cor. between two spins')
ax2.plot(t_nn,neigbouring_pairs,'kx--',label='N. N. Cor.')
ax2.errorbar(t_nn,(neigbouring_pairs),yerr=neigbouring_pairs_error/10, fmt=' ',color='k',capsize=3)

ax2.errorbar(t_nn,(pair_correlation),yerr=pair_correlation_errpr/10, fmt=' ',color='grey',capsize=3)
ax2.text(0.87,0.9,'Legend figure (a)')#,size='x-large')
#ax2.set_xticklabels(t_nn, fontsize= 10)

ax2.tick_params(direction='out', length=6, width=2, 
               grid_color='r', grid_alpha=0.5,labelsize=15)

ax2.legend()
#pair_correlation_errpr
fig.savefig('Correlation.png',dpi=900,bbox_inches='tight')
# Out:
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/3100010960.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(d2, fontsize= 15)

# %%
plt.plot(T,Magn/max(Magn),'x')
#plt.plot(T_b,abs(backward),'k')
plt.plot(T_b[:7],(backward[:7]),'r')

# %%
import matplotlib.pyplot as plt
from matplotlib.cbook import get_sample_data

im = plt.imread(get_sample_data('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png'))

fig, ax = plt.subplots()


# Place the image in the upper-right corner of the figure
#--------------------------------------------------------
# We're specifying the position and size in _figure_ coordinates, so the image
# will shrink/grow as the figure is resized. Remove "zorder=-1" to place the
# image in front of the axes.
newax = fig.add_axes([0.8, 0.8, 0.2, 0.2], anchor='NE', zorder=-1)
newax.imshow(im)


newax.axis('off')
ax.plot(range(10))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/178567081.py in <module>
#       2 from matplotlib.cbook import get_sample_data
#       3
# ----> 4 im = plt.imread(get_sample_data('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png'))
#       5
#       6 fig, ax = plt.subplots()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in get_sample_data(fname, asfileobj, np_load)
#     521             return path.open('r')
#     522         else:
# --> 523             return path.open('rb')
#     524     else:
#     525         return str(path)
#
# ~/opt/anaconda3/lib/python3.9/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1250         the built-in open() function does.
#    1251         """
# ...

# %%
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, ax = plt.subplots()

ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

arr_lena = mpimg.imread('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png')

imagebox = OffsetImage(arr_lena, zoom=0.2)

ab = AnnotationBbox(imagebox, (0.4, 0.6))

ax.add_artist(ab)

plt.grid()

plt.draw()
#plt.savefig('add_picture_matplotlib_figure.png',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/4031182874.py in <module>
#       9 ax.set_ylim(0, 1)
#      10
# ---> 11 arr_lena = mpimg.imread('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png')
#      12
#      13 imagebox = OffsetImage(arr_lena, zoom=0.2)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in imread(fname, format)
#    1499                     response = io.BytesIO(response.read())
#    1500                 return imread(response, format=ext)
# -> 1501     with img_open(fname) as image:
#    1502         return (_pil_png_to_float_array(image)
#    1503                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     107         if isPath(fp):
# ...

# %%
import matplotlib.pyplot as plt





plt.figure(figsize=(6, 4))

fig, (ax1, ax2,ax3)  = plt.subplots(1, 3,
                                sharey='row')




arr_lena = mpimg.imread('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png')

imagebox = OffsetImage(arr_lena, zoom=0.2)

ab = AnnotationBbox(imagebox, (0.4, 0.4))

ax1.add_artist(ab)


ax1.text(0.5, 0.5, 
              "left",
              color="green",
              fontsize=18, 
              ha='center')

ax2.text(0.5, 0.5, 
              "right",
              color="green",
              fontsize=18, 
              ha='center')
ax3.text(0.5, 0.5, 
              "right",
              color="green",
              fontsize=18, 
              ha='center')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/3603447701.py in <module>
#      13
#      14
# ---> 15 arr_lena = mpimg.imread('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png')
#      16
#      17 imagebox = OffsetImage(arr_lena, zoom=0.2)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in imread(fname, format)
#    1499                     response = io.BytesIO(response.read())
#    1500                 return imread(response, format=ext)
# -> 1501     with img_open(fname) as image:
#    1502         return (_pil_png_to_float_array(image)
#    1503                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     107         if isPath(fp):
#     108             # filename
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
img = Image.open('/Users/milos/Desktop/Ising_Model/Ising_pics/T.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/3605280267.py in <module>
# ----> 1 img = Image.open('/Users/milos/Desktop/Ising_Model/Ising_pics/T.png')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/milos/Desktop/Ising_Model/Ising_pics/T.png'

# %%
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/766465783.py in <module>
# ----> 1 plt.imshow(img)
#
# NameError: name 'img' is not defined

# %%
fig, (ax1, ax2,ax3)  = plt.subplots(1, 3,
                                sharey='row')

ax1.imshow(img)

img2 = Image.open('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png')
ax2.imshow(img2)
ax2.set_xticks([])
ax2.set_yticks([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/2033120530.py in <module>
#       2                                 sharey='row')
#       3
# ----> 4 ax1.imshow(img)
#       5
#       6 img2 = Image.open('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png')
#
# NameError: name 'img' is not defined

# %%
plt.figure(figsize=(4, 4))

fig, (ax1, ax2,ax3)  = plt.subplots(1, 3,
                                sharey='row')



img = Image.open('/Users/milos/Desktop/Ising_Model/Ising_pics/T.png')
ax1.imshow(img)
ax1.set_xticks([])
#ax1.set_yticks([])



img2 = Image.open('/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png')
ax2.imshow(img2)
ax2.set_xticks([])
ax2.set_yticks([])


img3 = Image.open('/Users/milos/Desktop/Ising_Model/Ising_pics/T_06.png')
ax3.imshow(img3)
ax3.set_xticks([])
ax3.set_yticks([])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/3666173119.py in <module>
#       6
#       7
# ----> 8 img = Image.open('/Users/milos/Desktop/Ising_Model/Ising_pics/T.png')
#       9 ax1.imshow(img)
#      10 ax1.set_xticks([])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/milos/Desktop/Ising_Model/Ising_pics/T.png'

# %%
1-1/320
# Out:
# 0.996875

# %%
##importing libraries
import numpy as np
from tqdm import tqdm 
import matplotlib.pyplot as plt
from matplotlib import patches as pt
N = 1000  ##number of spins
spin_values = np.array([1,-1])
Spin_array = np.random.choice(spin_values,size = N)  ##creating spin array
J = 1.0 ##spin interaction constant

iter = 500000

temp_array = np.linspace(0.05,5,20)  ##temperature array
N_iter = int(len(temp_array))  ##number of elements in temperature array ,
                                #cuz we have to calculate average for each temperature 

## list for storing average values and thier squared average
E_avg = np.array([])  ##list for average of energy
M_avg =np.array([]) ##list for magnetization i.e. total moment per spin 
E2_avg =np.array([])##list for storing square of energy
Entropy_avg = np.array([])  ##list for entropy
E_error = np.array([])
M_err =np.array([]) ##list for magnetization i.e. total moment per spin 
Entropy_err = np.array([])  ##list for entropy

for step in tqdm(range(N_iter)):
    
    T = temp_array[step]  ##indexing temperature
    
    Beta = 1.0/T 

    spin_array = Spin_array  ##we take  the last state as initial state every time for new temperature 
                                ## Calculating initial energy  
    energy = 0
    
    for k in range(N-1):
        energy += -J*spin_array[k]*spin_array[k+1]*spin_array[k-1]

    m = np.sum(spin_array)   ##total magnetic moment
        
    E = []    ##storing energy value in a list
    E_2 = []   ##storing energy*energy value in a list 
    Mag = []  ## ##storing magnetic moment value in a list
    Entropy_array = []  ## ##storing entropy value in a list
    
    for i in range(iter):
        ###these lines have already  been explained earlier
        r_n = np.random.randint(0,N)
        sigma_mu = spin_array[r_n]
        del_m = -2*sigma_mu
        
        if(r_n == 0):
            Sum = 2*J*sigma_mu*(spin_array[1]+spin_array[N-1])
        elif(r_n == N-1):
            Sum = 2*J*sigma_mu*(spin_array[N-2]+spin_array[0])
        else:
            Sum = 2*J*sigma_mu*(spin_array[r_n+1]+spin_array[r_n-1])

        del_E = Sum
        
        
        if(np.random.uniform()<np.exp(-Beta*del_E)):
            spin_array[r_n] = -1*spin_array[r_n]
            energy += del_E
            m+= del_m
        
            

        else:
            spin_array[r_n] =spin_array[r_n]
            

        
        if(i>=100000 and i%N==0):  ##after 1200000 iteration we will collect data at each Nth step
            KK = np.where(spin_array==1)
            n_positive = np.sum(np.ones(N)[KK])
            n_negative = N-n_positive
            
            T_p = np.math.factorial(N)/((np.math.factorial(n_positive))*(np.math.factorial(n_negative)))
            Entropy = np.log(T_p)       
            
            E.append(energy)
            E_2.append(energy**2)
            Mag.append(abs(m))
            Entropy_array.append(Entropy)
       
    ####calculating averages and storing them in numpy array
    E_avg = np.append(E_avg,(np.mean(np.array(E))))
    M_avg = np.append(M_avg,np.mean(np.array(Mag)))
    Entropy_avg = np.append(Entropy_avg,(np.mean(np.array(Entropy_array))))
    E2_avg = np.append(E2_avg,np.mean(np.array(E_2)))
    
    E_error = np.append(E_error,np.var(np.array(E_2)))
    Entropy_err = np.append(Entropy_err,(np.var(np.array(Entropy_array))))
    M_err = np.append(M_err,np.var(np.array(Mag)))
# Out:
#   0%|                                                    | 0/20 [00:00<?, ?it/s]/var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/721105361.py:79: DeprecationWarning: Using factorial() with floats is deprecated
#   T_p = np.math.factorial(N)/((np.math.factorial(n_positive))*(np.math.factorial(n_negative)))
# 100%|███████████████████████████████████████████| 20/20 [01:40<00:00,  5.01s/it]

# %%
B2 = (1.0/temp_array)**2  ##beta sqyare
C = (B2/N)*(E2_avg-(E_avg)**2)  ##specific heat

def DNA_zip(N,eps,x):
    return 1/(np.exp(-eps/x)+1)-N/(np.exp(-eps*(N+1)/x))


                  
##calculating analytically                        
T_theory = np.linspace(0.01,5,1000)
E_theory = -N*1.2*np.tanh(1.2/T_theory)+200
aa = 1./np.cosh(J/T_theory)
CV_theory = (N*J/(T_theory**2))*(aa**2)
Entropy_theory = np.log(2)+ E_theory/T_theory +N*np.log(2./aa)
#########################

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows = 2,ncols= 2,figsize = (16,10))

#ax1.set_title(" Average Energy vs temperature")
ax1.plot(temp_array,E_avg,'kx',label = "Computatinal")
ax1.plot(T_theory,E_theory,'r-',label = "Theoretical")
ax1.set_xlabel(r"Temperature $[T/T_C]$",fontsize=20)
ax1.set_ylabel(r"Average energy $[1/(4 keV)]$",fontsize=15)
ax1.errorbar(temp_array,(E_avg),yerr=E_error/1000000, fmt=' ',color='k',capsize=3)
ax1.text(0.05, 0.9, '(a)', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes,fontsize=20)
#ax1.set_ylim(-1000,.5)
ax1.legend()



#ax2.set_title(" Specific heat C vs temperature")
ax2.plot(temp_array,C,'kx',label = "Computatinal")
ax2.plot(T_theory,CV_theory/N,'r-',label = "Theoretical")
ax2.set_ylim(0,.5)
ax2.set_xlabel(r"Temperature $[T/T_C]$",fontsize=20)
ax2.set_ylabel(r"Heat capacity $[1/k_Bc]$",fontsize=15)
#ax2.errorbar(temp_array,(E_avg),yerr=E_error/100000, fmt=' ',color='k')
ax2.text(1.25, 0.9, '(b)', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes,fontsize=20)


ax2.legend()




#ax3.set_title(" Magnetization M vs temperature")
ax3.plot(temp_array,(-(M_avg))/max(M_avg)*1000+1100,'kx',label = "Computatinal")
tau=np.linspace(0.0015,stop=0.1,num=50)
ax3.plot(tau/0.02,(DNA_zip(1000,0.000001,tau)+2000),'r-',label = "Theoretical")
ax3.set_xlabel(r"Temperature $[T/T_C]$",fontsize=20)
ax3.set_ylabel(r"Average open bonds $ \langle n \rangle $",fontsize=15)
ax3.errorbar(temp_array,(-(M_avg))/max(M_avg)*1000+1100,yerr=M_err/100, fmt=' ',color='k',capsize=3)
ax3.text(0.05, -0.3, '(c)', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes,fontsize=20)
#ax3.set_xlim(-0.5, 5)

ax3.legend()




#ax4.set_title(" (b) ",fontsize=20)
ax4.plot(temp_array,(Entropy_avg),'x',color = 'k',label = "Computatinal")
#ax4.plot(T_theory,Entropy_theory*0.3,label = "Theoretical")
ax4.errorbar(temp_array,(Entropy_avg),yerr=Entropy_err/50, fmt=' ',color='k',capsize=3)
ax4.set_xlabel(r"Temperature $[T/T_C]$",fontsize=20)
ax4.set_ylabel(r"Entropy $[1/k_B]$ ",fontsize=15)
ax4.text(1.25, -0.3, '(d)', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes,fontsize=20)


ax4.legend()

#ax4.ylim(600, 700)
#ax4.set_ylim([600, 700])
plt.legend()
plt.show()

#fig.savefig('DNA_Zipping.png',bbox_inches='tight')
#fig.savefig('ax2_figure_expanded.png', bbox_inches=extent.expanded(1.1, 1.2))

# %%
def DNA_zip(N,eps,x):
    return 1/(np.exp(-eps/x)+1)-N/(np.exp(-eps*(N+1)/x))

# %%
plt.plot(T_theory,(Entropy_theory),label = "Theoretical")
plt.plot(temp_array,(Entropy_avg-min(Entropy_avg))/max(Entropy_avg)*10,color='k')

# %%
plt.plot(T_theory,(Entropy_theory),label = "Theoretical")
plt.plot(temp_array,(Entropy_avg),color='k')

# %%
##importing libraries
import numpy as np
from tqdm import tqdm 
import matplotlib.pyplot as plt
from matplotlib import patches as pt
N = 10  ##number of spins
spin_values = np.array([1,-1])
Spin_array = np.random.choice(spin_values,size = N)  ##creating spin array
J = 1.0 ##spin interaction constant



iter = 500000 ##yes we take such large number of iteration it may kill your computer :3
########################################################################################################
    
temp_array = np.linspace(0.05,4,10)  ##temperature array
N_iter = int(len(temp_array))  ##number of elements in temperature array , cuz we have to calculate average for each temperature 
## list for storing average values and thier squared average
E_avg = np.array([])  ##list for average of energy
M_avg =np.array([]) ##list for magnetization i.e. total moment per spin 
E2_avg =np.array([])##list for storing square of energy

Entropy_avg = np.array([])  ##list for entropy

for step in tqdm(range(N_iter)):
    
    T = temp_array[step]  ##indexing temperature
    
    Beta = 1.0/T 

    spin_array = Spin_array  ##we take  the last state as initial state every time for new temperature 
    ## Calculating initial energy  
    energy = 0
    for k in range(N-1):
        energy += -J*spin_array[k]*spin_array[k+1]

    m = np.sum(spin_array)   ##total magnetic moment
        
    E = []    ##storing energy value in a list
    E_2 = []   ##storing energy*energy value in a list 
    Mag = []  ## ##storing magnetic moment value in a list
    Entropy_array = []  ## ##storing entropy value in a list
    
    for i in range(iter):
        ###these lines have already  been explained earlier
        r_n = np.random.randint(0,N)
        sigma_mu = spin_array[r_n]
        del_m = -2*sigma_mu
        if(r_n == 0):
            Sum = 2*J*sigma_mu*(spin_array[1]+spin_array[N-1])
        elif(r_n == N-1):
            Sum = 2*J*sigma_mu*(spin_array[N-2]+spin_array[0])
        else:
            Sum = 2*J*sigma_mu*(spin_array[r_n+1]+spin_array[r_n-1])

        del_E = Sum
        
       

        

        if(np.random.uniform()<np.exp(-Beta*del_E)):
            spin_array[r_n] = -1*spin_array[r_n]
            energy += del_E
            m+= del_m
        
            

        else:
            spin_array[r_n] =spin_array[r_n]
            

        
        if(i>=100000 and i%N==0):  ##after 1200000 iteration we will collect data at each Nth step
            KK = np.where(spin_array==1)
            n_positive = np.sum(np.ones(N)[KK])
            n_negative = N-n_positive
            
            T_p = np.math.factorial(N)/((np.math.factorial(n_positive))*(np.math.factorial(n_negative)))
            Entropy = np.log(T_p)       
            
            E.append(energy)
            E_2.append(energy**2)
            Mag.append(abs(m))
            Entropy_array.append(Entropy)
       
    ####calculating averages and storing them in numpy array
    E_avg = np.append(E_avg,(np.mean(np.array(E))))
    M_avg = np.append(M_avg,np.mean(np.array(Mag)))
    Entropy_avg = np.append(Entropy_avg,(np.mean(np.array(Entropy_array))))
    E2_avg = np.append(E2_avg,np.mean(np.array(E_2)))
# Out:
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xj/0rh3vx9d5ts_r4zwpnk3lzfr0000gn/T/ipykernel_1912/140446135.py in <module>
#      44     for i in range(iter):
#      45         ###these lines have already  been explained earlier
# ---> 46         r_n = np.random.randint(0,N)
#      47         sigma_mu = spin_array[r_n]
#      48         del_m = -2*sigma_mu
#
# KeyboardInterrupt:

# %%
from matplotlib import style 
#style.use('Solarize_Light2')
## Specific Heat Array
B2 = (1.0/temp_array)**2  ##beta sqyare
C = (B2/N)*(E2_avg-(E_avg)**2)  ##specific heat


                  
##calculating analytically                        
T_theory = np.linspace(0.01,5,1000)
E_theory = -N*J*np.tanh(J/T_theory)
aa = 1./np.cosh(J/T_theory)
CV_theory = (N*J/(T_theory**2))*(aa**2)
Entropy_theory = np.log(2)+ E_theory/T_theory +N*np.log(2./aa)
#########################

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows = 2,ncols= 2,figsize = (16,10))

ax1.set_title(" Average Energy vs temperature")
ax1.scatter(temp_array,E_avg,color = 'k',label = "Computatinal")
ax1.plot(T_theory,E_theory,label = "Theoretical")



ax2.set_title(" Specific heat C vs temperature")
ax2.scatter(temp_array,C,color = 'k',label = "Computatinal")
ax2.plot(T_theory,CV_theory/N,label = "Theoretical")
ax2.set_ylim(0,.5)

ax3.set_title(" Magnetization M vs temperature")
ax3.plot(temp_array,M_avg/N,label = "Computatinal")





ax4.set_title(" Entropy vs temperature ")
ax4.scatter(temp_array,Entropy_avg,color = 'k',label = "Computatinal")
ax4.plot(T_theory,Entropy_theory,label = "Theoretical")
plt.legend()
plt.show()

# %%
np.random.choice(np.array([-1,1]), 3, p=[0.7,0.3])

# %%
def DNA_zip(N,eps,x):
    return 1/(np.exp(-eps/x)+1)-N/(np.exp(-eps*(N+1)/x))

# %%
T=np.linspace(0,stop=100,num=1000)

plt.plot(DNA_zip(1000,0.000000000001,T))

# %%
import pylab as pl


def rgb2gray(rgb):
    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray
 


def Boxcount(im):
    

    
    image=rgb2gray(pl.imread(im))

    # finding all the non-zero pixels
    pixels=[]
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            if image[i,j]>0:
                pixels.append((i,j))

    Lx=image.shape[1]
    Ly=image.shape[0]
    print (Lx, Ly)
    pixels=pl.array(pixels)
    print (pixels.shape)

    # computing the fractal dimension
    #considering only scales in a logarithmic list
    scales=np.logspace(0.01, 1, num=10, endpoint=False, base=2)
    Ns=[]
    # looping over several scales
    for scale in scales:
        #print ("======= Scale :",scale)
        # computing the histogram
        H, edges=np.histogramdd(pixels, bins=(np.arange(0,Lx,scale),np.arange(0,Ly,scale)))
        Ns.append(np.sum(H>0))

    # linear fit, polynomial of degree 1
    coeffs=np.polyfit(np.log(scales), np.log(Ns), 1)

    
    plt.figure(figsize=(10,5))
    pl.plot(np.log(scales),np.log(Ns), 'kx', mfc='none')
    pl.plot(np.log(scales), np.polyval(coeffs,np.log(scales)),'r')
    pl.xlabel('Grid Interval log $\omega$',fontsize=30)
    pl.ylabel('Occupied Cells log N',fontsize=30)
    pl.savefig('sierpinski_dimension.pdf')

    print ("The Hausdorff dimension is", -coeffs[0]) #the fractal dimension is the OPPOSITE of the fitting coefficient
    #np.savetxt("scaling.txt", list(zip(scales,Ns)))

# %%
import numpy as np
import pylab as pl
 
def rgb2gray(rgb):
    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray
 
image=rgb2gray(pl.imread("/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png"))

# finding all the non-zero pixels
pixels=[]
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        if image[i,j]>0:
            pixels.append((i,j))
 
Lx=image.shape[1]
Ly=image.shape[0]
print (Lx, Ly)
pixels=pl.array(pixels)
print (pixels.shape)
 
# computing the fractal dimension
#considering only scales in a logarithmic list
scales=np.logspace(0.01, 1, num=30, endpoint=False, base=2)
Ns=[]
# looping over several scales
for scale in scales:
    print ("======= Scale :",scale)
    # computing the histogram
    H, edges=np.histogramdd(pixels, bins=(np.arange(0,Lx,scale),np.arange(0,Ly,scale)))
    Ns.append(np.sum(H>0))
 
# linear fit, polynomial of degree 1
coeffs,cova=np.polyfit(np.log(scales), np.log(Ns), 1,cov=True)
 
pl.plot(np.log(scales),np.log(Ns), 'kx', mfc='none')
pl.plot(np.log(scales), np.polyval(coeffs,np.log(scales)),'r')
pl.xlabel('log $\epsilon$')
pl.ylabel('log N')
pl.savefig('sierpinski_dimension.pdf')
 
print ("The Hausdorff dimension is", -coeffs[0]) #the fractal dimension is the OPPOSITE of the fitting coefficient
np.savetxt("scaling.txt", list(zip(scales,Ns)))
# Out:
# 1088 1040
# (1129685, 2)
# ======= Scale : 1.0069555500567189
# ======= Scale : 1.0302539536200745
# ======= Scale : 1.054091423290738
# ======= Scale : 1.0784804316944516
# ======= Scale : 1.1034337400419594
# ======= Scale : 1.1289644048061311
# ======= Scale : 1.1550857845535842
# ======= Scale : 1.1818115469343653
# ======= Scale : 1.2091556758333615
# ======= Scale : 1.2371324786871727
# ======= Scale : 1.26575659397028
# ======= Scale : 1.295042998854425
# ======= Scale : 1.3250070170452075
# ======= Scale : 1.355664326800001
# ======= Scale : 1.3870309691313851
# ======= Scale : 1.4191233562003824
# ======= Scale : 1.4519582799038944
# ======= Scale : 1.485552920660829
# ======= Scale : 1.5199248564015158
# ======= Scale : 1.5550920717651169
# ======= Scale : 1.5910729675098374
# ======= Scale : 1.6278863701408692
# ======= Scale : 1.665551541761098
# ======= Scale : 1.704088190149732
# ======= Scale : 1.7435164790741244
# ======= Scale : 1.7838570388401855
# ...

# %%
plt.imshow(image)

# %%
cova

# %%
2/(1.4*10**(-23))

# %%
def Boxcount(im): 
    image=rgb2gray(pl.imread(im))
    # finding all the non-zero pixels
    pixels=[]
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            if image[i,j]>0:
                pixels.append((i,j))
    Lx=image.shape[1]
    Ly=image.shape[0]
    print (Lx, Ly)
    pixels=pl.array(pixels)
    print (pixels.shape)
    # computing the fractal dimension
    #considering only scales in a logarithmic list
    scales=np.logspace(0.01, 1, num=10, endpoint=False, base=2)
    Ns=[]
    # looping over several scales
    for scale in scales:
        #print ("======= Scale :",scale)
        # computing the histogram
        H, edges=np.histogramdd(pixels, bins=(np.arange(0,Lx,scale),np.arange(0,Ly,scale)))
        Ns.append(np.sum(H>0))
    # linear fit, polynomial of degree 1
    coeffs=np.polyfit(np.log(scales), np.log(Ns), 1)#,full=True)
    print(coeffs)
    plt.figure(figsize=(10,5))
    pl.plot(np.log(scales),np.log(Ns), 'kx', mfc='none',label='Data points')
    pl.plot(np.log(scales), np.polyval(coeffs,np.log(scales)),'r--',label='fit curve')
    pl.xlabel('inverse box number log $\omega$',fontsize=30)
    pl.ylabel('Occupied Cells log N',fontsize=30)
    plt.legend(fontsize=20)
    pl.savefig('sierpinski_dimension.png')
    print ("The Hausdorff dimension is", -coeffs[0],coeffs[1]) #the fractal dimension is the OPPOSITE of the fitting coefficient
    #np.savetxt("scaling.txt", list(zip(scales,Ns)))

# %%
Boxcount("/Users/milos/Desktop/Ising_Model/Ising_pics/T_C.png")
# Out:
# 1088 1040
# (1129685, 2)
# [-1.99992733 13.89121006]
# The Hausdorff dimension is 1.9999273316481199 13.891210056809273

# %%
coeffs
# Out:
# array([-1.99943504, 13.89137792])
